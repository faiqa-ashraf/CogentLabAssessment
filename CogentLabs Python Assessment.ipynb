# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.6.0-py3-none-any.whl (5.2 MB)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\admin\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Collecting certifi>=2021.10.8
#   Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sortedcontainers in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\admin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\admin\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, exceptiongroup, wsproto, trio, trio-websocket, certifi, selenium
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
# Successfully installed certifi-2022.9.24 exceptiongroup-1.0.4 h11-0.14.0 outcome-1.2.0 selenium-4.6.0 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.

# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\admin\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from BeautifulSoup4) (2.2.1)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
# Out:
# <ipython-input-17-49ad6f9a357c>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")

# %%
driver.get("https://www.pakwheels.com/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909#scroll_car_info")

# %%
#products=[]
#content = driver.page_source
#soup = BeautifulSoup(content)
#for a in soup.findAll('a',href=True, attrs={'class':'well'}):
#    name=a.find('p', attrs={'class':'detail-sub-heading'})
#    products.append(name.text)

# %%
#products
# Out:
# []

# %%
import requests
html_content1 = requests.get("https://www.pakwheels.com/used-cars").text
soup1=BeautifulSoup(html_content1,"lxml")
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en">
#  <head>
#   <style>
#    .async-hide { opacity: 0 !important}
#   </style>
#   <script>
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#         h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#         (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#     })(window,document.documentElement,'async-hide','dataLayer',4000,
#         {'GTM-MZCSH9L':true});
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#         ga('create', 'UA-642162-6', 'auto');
#         ga('require', 'GTM-MZCSH9L');
#         ga('send', 'pageview');
#   </script>
#   <script async="" defer="" src="https://apis.google.com/js/platform.js">
#   </script>
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <link as="style" href="https://wsa1.pakwheels.com/assets/desktop/application-9041d3700ad26d02c65a1e1386c84076.css" rel="preload"/>
#   <link href="https://wsa1.pakwheels.com/assets/desktop/application-9041d3700ad26d02c65a1e1386c84076.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link as="font" crossorigin="" href="https://wsa3.pakwheels.com/assets/Lato-Regular-35cf7e967cceb3804eaf9dccf8f1228b.woff2" rel="preload"/>
#   <link as="font" crossorigin="" href="https://wsa4.pakwheels.com/assets/Lato-Bold-a901503621ac1a177f5ef7b4c6e6671e.woff2" rel="preload"/>
#   <link as="style" href="https://wsa1.pakwheels.com/assets/desktop/fonts-woff2-7f9fe6d80cdb7f20cc2bd69fcc60ea59.css" onload="this.rel='stylesheet'" rel="preload"/>
#   <link as="style" href="https://wsa2.pakwheels.com/assets/fonts-base64-woff-9009644a9b2e88f0d021717f9b557f80.css" onload="this.rel='stylesheet'" rel="preload"/>
#   <link as="style" href="https://wsa2.pakwheels.com/assets/desktop/pwbodyicons-36e4fe3fe4da5a89fe866b5faa83b540.css" onload="this.rel='stylesheet'" rel="preload"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Pak eVentures" name="author"/>
#   <meta content="874489252431-6l96qm7o7q7udar6eujfp01slvi9s86h.apps.googleusercontent.com" name="google-signin-client_id"/>
#   <meta content="139280839547845" property="fb:app_id"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <meta content="pakwheels://used-cars" property="al:android:url"/>
#   <meta content="com.pakwheels" property="al:android:package"/>
#   <meta content="Pakwheels" property="al:android:app_name"/>
#   <link href="android-app://com.pakwheels/http/www.pakwheels.com/used-cars" rel="alternate"/>
#   <meta content="pakwheels://used-cars" property="al:ios:url"/>
#   <meta content="739776365" property="al:ios:app_store_id"/>
#   <meta content="Pakwheels" property="al:ios:app_name"/>
#   <link href="ios-app://739776365/pakwheels/used-cars" rel="alternate"/>
#   <title>
#    Buy Used Cars in Pakistan | PakWheels
#   </title>
#   <meta content="Buy Used Cars for Sale at Best Prices. #1 car buying &amp; selling website in Pakistan to buy &amp; sell used cars. Post FREE Ads or Find used cars at best prices." name="description"/>
#   <meta content="used cars, buy used car, pakistan, used car prices, sell used car, buy second hand car, karachi, lahore, islamabad, new cars for sale, honda, toyota, suzuki, mitsubishi, mercedes, bmw, new car price list, classifieds, latest rates" name="keywords"/>
#   <link href="/ur/used-cars/" hreflang="ur" rel="alternate"/>
#   <link href="/used-cars/" hreflang="x-default" rel="alternate"/>
#   <link href="https://www.pakwheels.com/used-cars/" rel="canonical"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Buy Used Cars in Pakistan | PakWheels" property="og:title"/>
#   <meta content="Buy Used Cars for Sale at Best Prices. #1 car buying &amp; selling website in Pakistan to buy &amp; sell used cars. Post FREE Ads or Find used cars at best prices." property="og:description"/>
#   <meta content="Pakwheels" property="og:site_name"/>
#   <meta content="https://wsa4.pakwheels.com/assets/meta/pakwheels_og_image-97e360e1e1a115ede1a9abaaec54b02d.jpg" property="og:image"/>
#   <meta content="https://www.pakwheels.com/used-cars/" property="og:url"/>
#   <meta content="product" name="twitter:card"/>
#   <meta content="Buy Used Cars in Pakistan | PakWheels" name="twitter:title"/>
#   <meta content="Buy Used Cars for Sale at Best Prices. #1 car buying &amp; selling website in Pakistan to buy &amp; sell used cars. Post FREE Ads or Find used cars at best prices." name="twitter:description"/>
#   <meta content="@pakwheels" name="twitter:site"/>
#   <meta content="@pakwheels" name="twitter:creator"/>
#   <meta content="https://wsa4.pakwheels.com/assets/meta/pakwheels_og_image-97e360e1e1a115ede1a9abaaec54b02d.jpg" name="twitter:image"/>
#   <meta content="https://wsa4.pakwheels.com/assets/meta/pakwheels_og_image-97e360e1e1a115ede1a9abaaec54b02d.jpg" name="image_src"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="OtcwWtJzzMOR/NnCzJR8yCEzmuE11SjDuGbd6DSWhcM=" name="csrf-token"/>
#   <link href="//wsa1.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//wsa2.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache1.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache2.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache3.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache4.pakwheels.com" rel="dns-prefetch"/>
#   <link href="/android-chrome-192x192.jpg" rel="apple-touch-icon"/>
#   <link href="/android-chrome-192x192.jpg" rel="icon"/>
#   <link href="https://plus.google.com/117392751510646293237" rel="publisher"/>
#   <link href="https://www.pakwheels.com/favicon.ico?t=1475740228" rel="shortcut icon" type="image/ico"/>
#   <script src="https://wsa4.pakwheels.com/assets/classified/top_javascript-2c0f803c5be2a04b66127624de5683d8.js" type="text/javascript">
#   </script>
#   <script src="https://wsa3.pakwheels.com/assets/classified/index_used_cars-a63fc44ef7b3481c4eca283136cf03dd.js" type="text/javascript">
#   </script>
#   <script>
#    var googletag = googletag || {};
#       googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
#    user_type = 'Anonymous';
#   is_mobile = '0';
#   newsletter_subscriber = 'false';
#   logged_in=false;
#   hashed_email='';
#          car_listings=bike_listings=parts_listings='';
#   pw_language = 'English';
#   </script>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-MMJ3TS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-9BLB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script>
#    var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     $(window).load(function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#               "//www.googletagservices.com/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     });
#   </script>
#   <script>
#    slots_to_be_refreshed = [];
#     googletag.cmd.push(function() {
#
#       var slot0 = googletag.defineSlot('/1012037/PakWheels_UsedCars_Landing_TopBanner_970x90', [970, 90] , 'div-gpt-PakWheels_UsedCars_Landing_TopBanner_970x90').addService(googletag.pubads());
#
#       var slot1 = googletag.defineSlot('/1012037/PakWheels_UsedCars_BTF_MediumRectangleBanner_300x250', [300, 250] , 'div-gpt-PakWheels_UsedCars_BTF_MediumRectangleBanner_300x250').addService(googletag.pubads());
#
#       var slot2 = googletag.defineSlot('/1012037/PakWheels_UsedCars_CenterBanner_BTF_728x90', [728, 90] , 'div-gpt-PakWheels_UsedCars_CenterBanner_BTF_728x90').addService(googletag.pubads());
#
#       var slot3 = googletag.defineSlot('/1012037/PakWheels_TopRightBar_ATF_415x91', [415, 91] , 'div-gpt-PakWheels_TopRightBar_ATF_415x91').addService(googletag.pubads());
#
#       var slot4 = googletag.defineSlot('/1012037/PakWheels_DesktopWeb_TopStickyBanner_450x30', [450, 30] , 'div-gpt-PakWheels_DesktopWeb_TopStickyBanner_450x30').addService(googletag.pubads());
#       googletag.pubads().collapseEmptyDivs();
#       customTargetUnit();
#       // googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#
#     function customTargetUnit(){
#       googletag.pubads().setTargeting("city", ($('#dfp_city').length > 0 && $('#dfp_city').val()) ? $('#dfp_city').val() : "");
#       googletag.pubads().setTargeting("make", ($('#dfp_make').length > 0 && $('#dfp_make').val()) ? $('#dfp_make').val() : "");
#       googletag.pubads().setTargeting("model", ($('#dfp_model').length > 0 && $('#dfp_model').val()) ? $('#dfp_model').val() : "");
#     }
#   </script>
#  </head>
#  <body>
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "WebPage",
#   "description": "Buy Used Cars for Sale at Best Prices. #1 car buying & selling website in Pakistan to buy & sell used cars. Post FREE Ads or Find used cars at best prices.",
#   "name": "Buy Used Cars in Pakistan",
#   "inLanguage": "en"
# }
#   </script>
#   <i class="ajax-search-loader search-loader-fixed">
#    <img alt="Pakwheels" src="https://wsa2.pakwheels.com/assets/ic_pakwheels_logo-5da88229484345f24ac496d90b23a83e.svg"/>
#   </i>
#   <div class="header clearfix header--fixed" id="header">
#    <div class="mini-nav clearfix">
#     <a class="pull-left btn-mini-app" data-target="#download_apps" data-toggle="modal" href="#" onclick="trackEvents('User', 'FromHeader - AppInstallClicked', 'Used Cars - Index');">
#      <i class="fa fa-mobile generic-red">
#      </i>
#      Download App via SMS
#     </a>
#     <div class="pull-left ml10" style="margin-top: -2px; margin-bottom: 2px;">
#      <div id="div-gpt-PakWheels_DesktopWeb_TopStickyBanner_450x30">
#       <script type="text/javascript">
#        googletag.cmd.push(function(){ googletag.display("div-gpt-PakWheels_DesktopWeb_TopStickyBanner_450x30"); });
#       </script>
#      </div>
#     </div>
#     <ul class="list-unstyled pull-right signin mt5" style="margin-right: -5px;">
#      <li class="urdu-img">
#       <a class="generic-red" href="/ur/used-cars" onclick="trackEvents('User','Language','Urdu');" trailing_slash="true">
#        <span>
#         اردو
#        </span>
#       </a>
#      </li>
#      <li>
#       <a data-target="#sign-up-popup" data-toggle="modal" href="javascript:void(0)" rel="nofollow">
#        Sign Up
#       </a>
#      </li>
#      <li>
#       <a data-target="#sign_in_pop_up" data-toggle="modal" href="javascript:void(0)" rel="nofollow">
#        Sign In
#       </a>
#      </li>
#      <li id="save-ads" style="display:none">
#       <a href="/saved-ads" id="saved-ads" onclick="trackEvents('SaveAd','ViewSaveAd','From - Header')" rel="nofollow">
#        <i class="fa fa-heart fa-large">
#        </i>
#        <span class="badge badge-important" id="saved-ads-count" style="display:none">
#         0
#        </span>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="main-nav clearfix">
#     <div class="navbar-header">
#      <a class="navbar-brand logo-white" href="/" loading="lazy" title="PakWheels.com">
#       <img alt="PakWheels.com" src="https://wsa1.pakwheels.com/assets/new-pw-logo-white-b8b4c00b25fde9cc8f514dc4947c266a.svg" title="PakWheels.com"/>
#      </a>
#      <a class="navbar-brand logo-blue" href="/" title="PakWheels.com">
#       <img alt="PakWheels.com" src="https://wsa3.pakwheels.com/assets/new-pw-logo-f3b51e30f3761934b0a70973db08c32f.svg" title="PakWheels.com"/>
#      </a>
#     </div>
#     <ul class="nav navbar-nav navbar-right">
#      <li class="active dropdown">
#       <a href="/used-cars/" title="Used Cars for sale in Pakistan">
#        Used Cars
#        <i class="fa fa-caret-down">
#        </i>
#       </a>
#       <ul class="dropdown-menu mega-navbar columns-4">
#        <li class="clearfix">
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/used-cars/search/-/" title="Used Cars Search">
#             <i class="fa fa-search">
#             </i>
#             <strong>
#              Find Used Cars for Sale
#             </strong>
#             <p>
#              Search from over 110k options
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/search/-/featured_1/?nf=true" onclick="trackEvents('CarSearch', 'From - SubTabs','Featured');" rel="nofollow" title="Featured Used Cars">
#             <i class="fa fa-star">
#             </i>
#             <strong>
#              Featured Used Cars
#             </strong>
#             <p>
#              View featured cars by PakWheels
#             </p>
#            </a>
#           </li>
#           <li>
#            <a class="sign-in-comp" href="/used-cars/sell" onclick="trackEvents('Navigation', 'SubTabs - SellYourCar','Used Cars');" title="Sell Cars in Pakistan">
#             <i class="fa fa-tag">
#             </i>
#             <strong>
#              Sell Your Car
#             </strong>
#             <p>
#              Post a free ad and sell your car quickly
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/dealers/" onclick="trackEvents('Dealers', 'From - Navigation');" title="Used Cars Dealers in Pakistan">
#             <i class="fa fa-book">
#             </i>
#             <strong>
#              Used Car Dealers
#             </strong>
#             <p>
#              Find used car dealers near your
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/price-calculator/" rel="nofollow" title="Car Price Valuation">
#             <i class="fa fa-bullseye">
#             </i>
#             <strong>
#              Price Calculator
#             </strong>
#             <p>
#              Calculate the market price of cars
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/used-cars/pakwheels-certified/" title="Cars with the PakWheels seal of approval">
#             <i class="fa fa-check-square-o">
#             </i>
#             <strong>
#              PakWheels Certified Cars
#             </strong>
#             <p>
#              Cars with the PakWheels seal of approval
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/products/pakwheels-inspection" onclick="trackEvents('CarSure', 'From - NavigationMenu','');" title="Get Your Car Inspected by PakWheels Experts | PakWheels">
#             <i class="fa fa-thumbs-o-up">
#             </i>
#             <strong>
#              PakWheels Car Inspection
#             </strong>
#             <p>
#              Car with detailed PakWheels Inspection reports
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/products/pakwheels-sell-it-for-me/" onclick="trackEvents('SellItForMe', ' View Product Page','From - NavigationMenu');" title="">
#             <i class="fa fa-thumbs-o-up">
#             </i>
#             <strong>
#              PakWheels Sell It For Me
#             </strong>
#             <p>
#              Let PakWheels sell your car hassle free for you
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/auction-sheet-verification/" title="Authentic Auction Sheets for your peace of mind">
#             <i class="fa fa-file-text">
#             </i>
#             <strong>
#              Auction Sheet Verification
#             </strong>
#             <p>
#              Authentic Auction Sheets for your peace of mind
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <i class="fa fa-map-marker" style="font-size: 16px">
#             </i>
#             <strong>
#              Popular Cities
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/karachi/24857" title="Used Cars for sale in Karachi">
#             <p class="city-name">
#              Karachi
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/lahore/24858" title="Used Cars for sale in Lahore">
#             <p class="city-name">
#              Lahore
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/islamabad/24856" title="Used Cars for sale in Islamabad">
#             <p class="city-name">
#              Islamabad
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/rawalpindi/24831" title="Used Cars for sale in Rawalpindi">
#             <p class="city-name">
#              Rawalpindi
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/peshawar/24821" title="Used Cars for sale in Peshawar">
#             <p class="city-name">
#              Peshawar
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/faisalabad/24753" title="Used Cars for sale in Faisalabad">
#             <p class="city-name">
#              Faisalabad
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/multan/24810" title="Used Cars for sale in Multan">
#             <p class="city-name">
#              Multan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/gujranwala/24763" title="Used Cars for sale in Gujranwala">
#             <p class="city-name">
#              Gujranwala
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg aria-hidden="true" class="svg-inline--fa fa-car fa-w-16" data-icon="car" data-prefix="fas" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M499.99 176h-59.87l-16.64-41.6C406.38 91.63 365.57 64 319.5 64h-127c-46.06 0-86.88 27.63-103.99 70.4L71.87 176H12.01C4.2 176-1.53 183.34.37 190.91l6 24C7.7 220.25 12.5 224 18.01 224h20.07C24.65 235.73 16 252.78 16 272v48c0 16.12 6.16 30.67 16 41.93V416c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-32h256v32c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-54.07c9.84-11.25 16-25.8 16-41.93v-48c0-19.22-8.65-36.27-22.07-48H494c5.51 0 10.31-3.75 11.64-9.09l6-24c1.89-7.57-3.84-14.91-11.65-14.91zm-352.06-17.83c7.29-18.22 24.94-30.17 44.57-30.17h127c19.63 0 37.28 11.95 44.57 30.17L384 208H128l19.93-49.83zM96 319.8c-19.2 0-32-12.76-32-31.9S76.8 256 96 256s48 28.71 48 47.85-28.8 15.95-48 15.95zm320 0c-19.2 0-48 3.19-48-15.95S396.8 256 416 256s32 12.76 32 31.9-12.8 31.9-32 31.9z" fill="currentColor">
#              </path>
#             </svg>
#             <strong>
#              Popular Models
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/toyota-corolla/688" title="Toyota Corolla Cars for sale in Pakistan">
#             <p class="city-name">
#              Toyota Corolla
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/honda-civic/642" title="Honda Civic Cars for sale in Pakistan">
#             <p class="city-name">
#              Honda Civic
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/honda-city/664" title="Honda City Cars for sale in Pakistan">
#             <p class="city-name">
#              Honda City
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/suzuki-cultus/660" title="Suzuki Cultus Cars for sale in Pakistan">
#             <p class="city-name">
#              Suzuki Cultus
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/suzuki-mehran/661" title="Suzuki Mehran Cars for sale in Pakistan">
#             <p class="city-name">
#              Suzuki Mehran
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/toyota-vitz/781" title="Toyota Vitz Cars for sale in Pakistan">
#             <p class="city-name">
#              Toyota Vitz
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/suzuki-alto/658" title="Suzuki Alto Cars for sale in Pakistan">
#             <p class="city-name">
#              Suzuki Alto
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/toyota-prado/38678" title="Toyota Prado Cars for sale in Pakistan">
#             <p class="city-name">
#              Toyota Prado
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="/new-cars/" title="Research New Cars in Pakistan, Car Prices, Reviews and Comparisons">
#        New Cars
#        <i class="fa fa-caret-down">
#        </i>
#       </a>
#       <ul class="dropdown-menu mega-navbar columns-3">
#        <li class="clearfix">
#         <div class="col-md-4">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/new-cars/" title="Research New Cars in Pakistan, Car Prices, Reviews and Comparisons">
#             <i class="fa fa-search">
#             </i>
#             <strong>
#              Find New Cars
#             </strong>
#             <p>
#              See new cars in Pakistan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/compare/" title="Car Comparisons">
#             <i class="fa fa-columns">
#             </i>
#             <strong>
#              Car Comparisons
#             </strong>
#             <p>
#              Compare cars and find their differences
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/reviews/" title="Reviews">
#             <i class="fa fa-comments">
#             </i>
#             <strong>
#              Reviews
#             </strong>
#             <p>
#              Read reviews of all cars in Pakistan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/pricelist/" title="Car Prices in Pakistan">
#             <i class="fa fa-tags">
#             </i>
#             <strong>
#              Prices
#             </strong>
#             <p>
#              See prices of new cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/on-road-price" onclick="trackEvents('OnRoadPrice', 'From - Navigation','');" title="Get Instant On Road Price">
#             <i class="fa fa-road">
#             </i>
#             <strong>
#              On Road Price
#             </strong>
#             <p>
#              Calculate the total cost of new car
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/dealers/" onclick="trackEvents('Dealers', 'From - Navigation','new cars');" title="New Cars Dealers in Pakistan">
#             <i class="fa fa-book">
#             </i>
#             <strong>
#              New Car Dealers
#             </strong>
#             <p>
#              Find new car dealers
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-4">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg fill="none" height="17" viewbox="0 0 17 17" width="17" xmlns="http://www.w3.org/2000/svg">
#              <path d="M11.5782 6.09819C11.4327 5.6691 11.0255 5.36365 10.5455 5.36365H2.54545C2.06545 5.36365 1.66545 5.6691 1.51273 6.09819L0 10.4546V16.2727C0 16.6727 0.327273 17 0.727273 17H1.45455C1.85455 17 2.18182 16.6727 2.18182 16.2727V15.5455H10.9091V16.2727C10.9091 16.6727 11.2364 17 11.6364 17H12.3636C12.7636 17 13.0909 16.6727 13.0909 16.2727V10.4546L11.5782 6.09819ZM2.54545 13.3636C1.94182 13.3636 1.45455 12.8764 1.45455 12.2727C1.45455 11.6691 1.94182 11.1818 2.54545 11.1818C3.14909 11.1818 3.63636 11.6691 3.63636 12.2727C3.63636 12.8764 3.14909 13.3636 2.54545 13.3636ZM10.5455 13.3636C9.94182 13.3636 9.45455 12.8764 9.45455 12.2727C9.45455 11.6691 9.94182 11.1818 10.5455 11.1818C11.1491 11.1818 11.6364 11.6691 11.6364 12.2727C11.6364 12.8764 11.1491 13.3636 10.5455 13.3636ZM1.45455 9.72728L2.54545 6.45456H10.5455L11.6364 9.72728H1.45455Z" fill="#373737">
#              </path>
#              <path d="M11.6363 10.2273C14.3225 10.2273 16.5 8.04975 16.5 5.36364C16.5 2.67752 14.3225 0.5 11.6363 0.5C8.95023 0.5 6.77271 2.67752 6.77271 5.36364C6.77271 8.04975 8.95023 10.2273 11.6363 10.2273Z" fill="#373737" stroke="white">
#              </path>
#              <path d="M13.7879 5.03223L12.8481 5.99886L13.057 7.35214C13.057 7.40737 13.0309 7.49022 12.9787 7.51784C12.9526 7.54546 12.9265 7.54546 12.8743 7.54546C12.8481 7.54546 12.822 7.54546 12.7959 7.51784L11.6473 6.88263L10.4988 7.51784C10.4466 7.54546 10.3682 7.54546 10.316 7.49023C10.2638 7.46261 10.2377 7.37975 10.2377 7.32452L10.4466 5.97124L9.5068 5.00461C9.45459 4.94937 9.45459 4.89414 9.45459 4.81128C9.48069 4.75605 9.5329 4.70081 9.58511 4.70081L10.8642 4.50749L11.4385 3.26468C11.4907 3.15421 11.6996 3.15421 11.7518 3.26468L12.3261 4.50749L13.6052 4.70081C13.7344 4.70081 13.8833 4.93125 13.7879 5.03223Z" fill="white">
#              </path>
#             </svg>
#             <strong>
#              Popular Brands
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/suzuki/" onclick="trackEvents('NewCars','From - Header','Suzuki')" title="Suzuki Cars in Paksitan">
#             <p class="city-name">
#              Suzuki Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/toyota/" onclick="trackEvents('NewCars','From - Header','Toyota')" title="Toyota Cars in Paksitan">
#             <p class="city-name">
#              Toyota Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/honda/" onclick="trackEvents('NewCars','From - Header','Honda')" title="Honda Cars in Paksitan">
#             <p class="city-name">
#              Honda Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/kia/" onclick="trackEvents('NewCars','From - Header','KIA')" title="KIA Cars in Paksitan">
#             <p class="city-name">
#              KIA Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/hyundai/" onclick="trackEvents('NewCars','From - Header','Hyundai')" title="Hyundai Cars in Paksitan">
#             <p class="city-name">
#              Hyundai Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/changan/" onclick="trackEvents('NewCars','From - Header','Changan')" title="Changan Cars in Paksitan">
#             <p class="city-name">
#              Changan Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/mg/" onclick="trackEvents('NewCars','From - Header','MG')" title="MG Cars in Paksitan">
#             <p class="city-name">
#              MG Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/bmw/" onclick="trackEvents('NewCars','From - Header','BMW')" title="BMW Cars in Paksitan">
#             <p class="city-name">
#              BMW Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/audi/" onclick="trackEvents('NewCars','From - Header','Audi')" title="Audi Cars in Paksitan">
#             <p class="city-name">
#              Audi Cars
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-4">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg aria-hidden="true" class="svg-inline--fa fa-car fa-w-16" data-icon="car" data-prefix="fas" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M499.99 176h-59.87l-16.64-41.6C406.38 91.63 365.57 64 319.5 64h-127c-46.06 0-86.88 27.63-103.99 70.4L71.87 176H12.01C4.2 176-1.53 183.34.37 190.91l6 24C7.7 220.25 12.5 224 18.01 224h20.07C24.65 235.73 16 252.78 16 272v48c0 16.12 6.16 30.67 16 41.93V416c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-32h256v32c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-54.07c9.84-11.25 16-25.8 16-41.93v-48c0-19.22-8.65-36.27-22.07-48H494c5.51 0 10.31-3.75 11.64-9.09l6-24c1.89-7.57-3.84-14.91-11.65-14.91zm-352.06-17.83c7.29-18.22 24.94-30.17 44.57-30.17h127c19.63 0 37.28 11.95 44.57 30.17L384 208H128l19.93-49.83zM96 319.8c-19.2 0-32-12.76-32-31.9S76.8 256 96 256s48 28.71 48 47.85-28.8 15.95-48 15.95zm320 0c-19.2 0-48 3.19-48-15.95S396.8 256 416 256s32 12.76 32 31.9-12.8 31.9-32 31.9z" fill="currentColor">
#              </path>
#             </svg>
#             <strong>
#              Popular New Cars
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/honda/civic/" title="Honda Civic">
#             <p class="city-name">
#              Honda Civic
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/suzuki/alto/" title="Suzuki Alto">
#             <p class="city-name">
#              Suzuki Alto
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/suzuki/cultus/" title="Suzuki Cultus">
#             <p class="city-name">
#              Suzuki Cultus
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars
355 21.4887 13.4837C20.1883 14.5781 18.6819 15.1833 16.9823 15.2992C16.8278 15.312 16.6089 15.4408 16.5317 15.5695C15.7334 16.8442 16.0553 16.6511 14.5746 16.6382C13.7506 16.6253 12.9394 16.5867 12.1154 16.561C12.0768 16.5352 12.0382 16.5223 11.948 16.4966ZM16.0553 8.79709C15.8622 8.59108 15.7077 8.34645 15.4888 8.23057C15.1798 8.07607 14.8836 8.23058 14.6776 8.51383C14.0596 9.35073 13.4416 10.1876 12.8364 11.0374C12.5789 11.3979 12.6433 11.8228 12.9652 12.0417C13.3 12.2734 13.712 12.1833 13.9952 11.7971C14.5231 11.076 15.0639 10.3421 15.5789 9.59537C15.7463 9.37648 15.8622 9.13185 16.0553 8.79709Z" fill="#373737">
#              </path>
#              <path d="M33.9521 14.3593C33.9521 17.3593 31.4929 19.8443 28.5058 19.8443C25.5187 19.8443 23.0209 17.3851 23.0337 14.3851C23.0466 11.3594 25.4157 9.00317 28.274 8.91305C31.4542 8.82292 33.9521 11.2821 33.9521 14.3593ZM26.9221 10.6255C27.2569 11.1534 27.5916 11.6684 27.9135 12.1834C28.2998 12.7885 28.686 13.3937 29.0594 14.0117C29.2654 14.3593 29.1753 14.7456 28.8663 14.9387C28.5444 15.1447 28.1581 15.0546 27.9006 14.7198C27.8491 14.6426 27.7976 14.5525 27.7461 14.4752C27.0895 13.4452 26.4328 12.4152 25.7633 11.3851C24.5788 12.2091 23.832 14.5782 24.9393 16.458C26.0723 18.3765 28.5058 19.0589 30.4628 17.9902C32.4199 16.9087 33.1667 14.4752 32.1366 12.5182C31.1324 10.5611 28.7633 9.69845 26.9221 10.6255Z" fill="#373737">
#              </path>
#              <path d="M0 14.3721C0.0257508 11.2434 2.49783 8.9516 5.43341 8.9001C8.42051 8.86147 10.9312 11.385 10.9441 14.3464C10.9441 17.3464 8.45913 19.8313 5.47204 19.8313C2.47208 19.8442 0 17.3721 0 14.3721ZM1.35192 14.3593C1.35192 16.6253 3.20597 18.4923 5.45917 18.4923C7.68661 18.4923 9.55354 16.6382 9.57929 14.3979C9.59217 12.1576 7.69948 10.2263 5.48492 10.252C3.07722 10.2778 1.39054 12.1576 1.35192 14.3593Z" fill="#373737">
#              </path>
#              <path d="M5.43371 17.2176C7.01944 17.2176 8.30492 15.9322 8.30492 14.3464C8.30492 12.7607 7.01944 11.4752 5.43371 11.4752C3.84798 11.4752 2.5625 12.7607 2.5625 14.3464C2.5625 15.9322 3.84798 17.2176 5.43371 17.2176Z" fill="#373737">
#              </path>
#             </svg>
#             <strong>
#              Used Bikes Listings
#             </strong>
#             <p>
#              Search from over 5000+ options
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-bikes/search/-/featured_1/" rel="nofollow" title="Featured Used Bikes">
#             <i class="fa fa-star">
#             </i>
#             <strong>
#              Featured Used Bikes
#             </strong>
#             <p>
#              Browse our featured bikes
#             </p>
#            </a>
#           </li>
#           <li>
#            <a class="sign-in-comp" href="/used-bikes/sell" onclick="trackEvents('Navigation', 'Tabs - SellYourBike','');" title="Sell Bikes in Pakistan">
#             <i class="fa fa-tag">
#             </i>
#             <strong>
#              Sell Your Bike
#             </strong>
#             <p>
#              Post a free ad and sell your bike quickly
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a href="
#              </path>
# ...
#            4x4 Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/660cc-cars/190519" title="660cc Cars for Sale in Pakistan">
#            660cc Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/1000cc-cars/190769" title="1000cc Cars for Sale in Pakistan">
#            1000cc Cars
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3">
#         <ul class="nomargin footer-links list-unstyled" id="footer-body_type">
#          <li>
#           <h5>
#            Cars by Body Type
#           </h5>
#          </li>
#          <li>
#           <a href="/used-cars/sedan/107775" title="Sedan Cars for Sale">
#            Sedan
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/hatchback/107774" title="Hatchback Cars for Sale">
#            Hatchback
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/suv/107776" title="SUV Cars for Sale">
#            SUV
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/crossover/107782" title="Crossover Cars for Sale">
#            Crossover
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/mini-van/107785" title="Mini Van Cars for Sale">
#            Mini Van
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/double-cabin/266839" title="Double Cabin Cars for Sale">
#            Double Cabin
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/compact-sedan/441106" title="Compact sedan Cars for Sale">
#            Compact sedan
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/mpv/145760" title="MPV Cars for Sale">
#            MPV
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3">
#         <ul class="nomargin footer-links list-unstyled" id="footer-color">
#          <li>
#           <h5>
#            Cars by Color
#           </h5>
#          </li>
#          <li>
#           <a href="/used-cars/white/107804" title="White Cars for Sale">
#            White Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/silver/107802" title="Silver Cars for Sale">
#            Silver Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/black/107787" title="Black Cars for Sale">
#            Black Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/grey/107794" title="Grey Cars for Sale">
#            Grey Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/blue/107788" title="Blue Cars for Sale">
#            Blue Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/red/107801" title="Red Cars for Sale">
#            Red Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/green/107793" title="Green Cars for Sale">
#            Green Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/gold/107792" title="Gold Cars for Sale">
#            Gold Cars
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3">
#         <ul class="nomargin footer-links list-unstyled" id="footer-province">
#          <li>
#           <h5>
#            Cars by Province
#           </h5>
#          </li>
#          <li>
#           <a href="/used-cars/punjab/201902" title="Punjab Cars for Sale">
#            Cars in Punjab
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/sindh/201932" title="Sindh Cars for Sale">
#            Cars in Sindh
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/kpk/201917" title="KPK Cars for Sale">
#            Cars in KPK
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/balochistan/201947" title="Balochistan Cars for Sale">
#            Cars in Balochistan
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/azad-kashmir/201953" title="Azad Kashmir Cars for Sale">
#            Cars in Azad Kashmir
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/federally-administered-tribal-areas/201951" title="Federally Administered Tribal Areas Cars for Sale">
#            Cars in Federally Administered Tribal Areas
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="col-md-3">
#       <div class="row">
#        <div class="col-md-12" style="padding-left: 0px;">
#         <ul class="nomargin footer-links list-unstyled">
#          <li>
#           <h5>
#            Sell On PakWheels
#           </h5>
#          </li>
#          <li>
#           <a class="sign-in-comp" href="/used-cars/sell" id="foot-sell-car" onclick="trackEvents('UsedCars', 'Add Car', 'From - Footer')" title="Sell Your Car in Pakistan">
#            Sell Your Car
#           </a>
#          </li>
#          <li>
#           <a class="sign-in-comp" href="/used-bikes/sell" id="foot-sell-bike" onclick="trackEvents('UsedBikes','Sellform','From - Footer')" title="Sell Your Bike in Pakistan">
#            Sell Your Bike
#           </a>
#          </li>
#          <li>
#           <a class="sign-in-comp" href="/accessories-spare-parts/sell" id="foot-sell-accessory" onclick="trackEvents('Accessories','Sell','From - Footer')" title="Sell Autoparts &amp; Accessories in Pakistan">
#            Sell Accessory
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="row">
#        <form class="form-horizontal newsletter-subscription" id="subscribe_newsletter">
#         <h5>
#          Subscribe to our Newsletter
#         </h5>
#         <div id="newsletter-message" style="display:none; font-size: 14px; color: #999999;">
#         </div>
#         <div class="form-fields">
#          <input id="email" name="email" placeholder="name@email.com" style="width: 100%; font-family: arial;" type="text"/>
#          <button class="btn btn-success btn-xs" type="submit">
#           Subscribe
#          </button>
#          <div class="error-message" style="color:red;">
#          </div>
#         </div>
#        </form>
#        <div class="mb30 footer-social clearfix">
#         <h5>
#          Follow Us
#         </h5>
#         <ul class="list-unstyled list-inline networks primary-lang">
#          <li>
#           <a class="twitter" href="https://www.twitter.com/pakwheels" rel="nofollow" target="_blank" title="Follow Us On Twitter">
#            <i class="fa fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="facebook" href="https://www.facebook.com/pakwheels" rel="nofollow" target="_blank" title="Follow Us On Facebook">
#            <i class="fa fa-facebook">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="googleplus" href="https://plus.google.com/117775652035228984610" rel="me" target="_blank" title="Follow Us On Google Plus">
#            <i class="fa fa-google-plus">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="pinterest" href="https://pinterest.com/pakwheels/" rel="nofollow" target="_blank" title="Follow Us On Pinterest">
#            <i class="fa fa-pinterest">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="instagram" href="https://instagram.com/pakwheels" rel="nofollow" target="_blank" title="Follow Us On Instagram">
#            <i class="fa fa-instagram">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="youtube" href="https://www.youtube.com/user/pakwheels" rel="me" target="_blank" title="Follow Us On Youtube">
#            <i class="fa fa-youtube">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div>
#         <h5>
#          <a class="generic-white" href="/apps">
#           Download Mobile Apps
#          </a>
#         </h5>
#         <a href="https://play.google.com/store/apps/details?id=com.pakwheels&amp;referrer=utm_source%3Dpakwheels.com%26utm_medium%3Dweb-link%26utm_content%3Dfooter%26utm_campaign%3Dorganic-installs" target="_blank" title="PakWheels Android App">
#          <img alt="Google-play-badge" height="40" loading="lazy" src="https://wsa4.pakwheels.com/assets/google-play-badge-f4bed6cbd8a3a1be7c79377c4441447a.svg"/>
#         </a>
#         <a href="https://click.google-analytics.com/redirect?tid=UA-642162-19&amp;url=https%3A%2F%2Fitunes.apple.com%2Fpk%2Fapp%2Fpakwheels%2Fid739776365%3Fmt%3D8&amp;aid=com.pakwheels.www&amp;idfa={idfa}&amp;cs=pakwheels.com&amp;cm=web-link&amp;cn=organic-installs&amp;cc=footer&amp;hash=md5" target="_blank" title="PakWheels iOS App">
#          <img alt="App-store-badge" height="40" loading="lazy" src="https://wsa1.pakwheels.com/assets/app-store-badge-4d05ff70e5546f31e3891739ea40abad.svg"/>
#         </a>
#         <a href="https://appgallery.huawei.com/#/app/C101437147" target="_blank" title="PakWheels Android App">
#          <img alt="Huawei-store-badge" height="40" loading="lazy" src="https://wsa4.pakwheels.com/assets/huawei-store-badge-7ad06f9ffe74b644d49c6221af98f5b3.svg"/>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <hr class="dark"/>
#     <div class="copyright footer-links mt30">
#      Copyright &amp;copy 2003 - 2022 PakWheels (Pvt) Ltd. - All Rights Reserved.
#      <br/>
#      <a href="/main/terms" rel="nofollow" title="Terms of Service">
#       Terms of Service
#      </a>
#      |
#      <a href="/privacy-policy" rel="nofollow" title="Privacy Policy">
#       Privacy Policy
#      </a>
#     </div>
#     <p class="copyright mt5">
#      Reproduction of material from any PakWheels.com pages without permission is strictly prohibited.
#     </p>
#    </div>
#   </div>
#   <div data-auto_select="false" data-cancel_on_tap_outside="false" data-client_id="874489252431-6l96qm7o7q7udar6eujfp01slvi9s86h.apps.googleusercontent.com" data-context="use" data-login_uri="https://www.pakwheels.com/confirm-google-login" data-nonce="" id="g_id_onload">
#   </div>
#   <script>
#    $(function(){
#       var make= $('#UsedManID').val();
#       if (make) {
#         updateModels('car',make, $('#UsedModelID'), 'All Models'); reloadChosen('#UsedModelID');
#         updateVersion('car',$('#UsedModelID').val(), make, $('#UsedVersionID'), 'All Versions');reloadChosen('#UsedVersionID');
#       }
#       $(".search-main").bind('keydown',function(e) {
#         if(e.which === 13 && $(".chzn-single-with-drop").length==0 &&!$("select").is(":focus")) {
#             $('.search-main #used-cars-search-btn').click();
#         }
#       });
#     });
#   </script>
#   <script>
#    $('.nav-dropdown-menu').on('mouseover', function() {
#         $(this).parent().addClass('open');
#       });
#       $('.nav-dropdown-menu').on('mouseout', function() {
#         $(this).parent().removeClass('open');
#       });
#       $(document).ready(function (){ $('#navbar_static_top').attr('data-offset-top', $('.advertisement').innerHeight() + $('.header').innerHeight());
#
#         $("#user-menu,#lang-menu").click(function(e){
#           $(this).toggleClass("open");
#             e.stopPropagation();
#         });
#
#       });
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
#     (function(d, s, id) {
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.8&appId=139280839547845";
#       fjs.parentNode.insertBefore(js, fjs);
#       }(document, 'script', 'facebook-jssdk'));
#
# //]]>
#   </script>
#   <script>
#    var om_load_jquery = false;
#   </script>
#   <div id="om-dxawge5rc65nrwtv-holder">
#   </div>
#   <script>
#    $(window).load(function(){
#           var dxawge5rc65nrwtv,dxawge5rc65nrwtv_poll=function(){var r=0;return function(n,l){clearInterval(r),r=setInterval(n,l)}}();!function(e,t,n){if(e.getElementById(n)){dxawge5rc65nrwtv_poll(function(){if(window['om_loaded']){if(!dxawge5rc65nrwtv){dxawge5rc65nrwtv=new OptinMonsterApp();return dxawge5rc65nrwtv.init({u:"10331.222818",staging:0,dev:0});}}},25);return;}var d=false,o=e.createElement(t);o.id=n, o.async=true, o.src="//a.optinmonster.com/app/js/api.min.js",o.onload=o.onreadystatechange=function(){if(!d){if(!this.readyState||this.readyState==="loaded"||this.readyState==="complete"){try{d=om_loaded=true;dxawge5rc65nrwtv=new OptinMonsterApp();dxawge5rc65nrwtv.init({u:"10331.222818",staging:0,dev:0});o.onload=o.onreadystatechange=null;}catch(t){}}}};(document.getElementsByTagName("head")[0]||document.documentElement).appendChild(o)}(document,"script","omapi-script");
#         });
#   </script>
#   <!-- Go to www.addthis.com/dashboard to customize your tools -->
#   <script type="text/javascript">
#    $(window).on("load", function() {
#           var f=document.getElementsByTagName('script')[0],
#               j=document.createElement('script');j.async=true;j.src=
#               '//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-570bb55ad090476b';f.parentNode.insertBefore(j,f);
#         });
#   </script>
#   <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#   <script>
#    var OneSignal = window.OneSignal || [];
#       OneSignal.push(["init", {
#         appId: "2cca5b5e-e246-46f7-9a26-f638f0d42a03",
#         safari_web_id: "web.onesignal.auto.5e769637-3ad0-4829-bde6-e4b31d264ae2",
#         autoRegister: false, /* Set to true to automatically prompt visitors */
#         httpPermissionRequest: {
#             enable: true
#         },
#         notifyButton: {
#           enable: false /* Set to false to hide */
#         },
#         promptOptions: {
#             siteName: 'OneSignal Documentation',
#             actionMessage: "Subscribe to our push notification for the latest news & Updates",
#             acceptButtonText: "ALLOW",
#             cancelButtonText: "NO THANKS"
#         },
#         path: '/OneSignalDesktop/',
#       }]);
#       OneSignal.push(function() {
#           OneSignal.isPushNotificationsEnabled(function(isEnabled) {
#               if (isEnabled)
#                   console.log("Push notifications are enabled!");
#               else{
#                 OneSignal.push(function() {
#                   OneSignal.showHttpPrompt();
#                 });
#               }
#           });
#
#           OneSignal.on('subscriptionChange', function (isSubscribed) {
#               console.log("The user's subscription status has change, isSubscribed:", isSubscribed);
#               if (isSubscribed)
#               {
#                 trackEvents('User','From-browser PushSubscriptionDone', "used_cars",true);
#               }else{
#                  trackEvents('User','From-browser PushSubscriptionClosed', "used_cars",true);
#               }
#               OneSignal.getUserId( function(userId) {
#                   console.log("OneSignal User ID:", userId);
#                   // Make a POST call to GA with the subscription data and userId aka playerId
#                   // trackEvents('User','Subscription_Change', '',true);
#                   // ga('send', 'event', 'Subscription_Change', isSubscribed, userId);
#               });
#           });
#
#           OneSignal.on('popoverCancelClick', function(permissionChange) {
#             trackEvents('User','PushSubscriptionClosed', "used_cars",true);
#             console.log('New permission state:', permissionChange);
#           });
#           OneSignal.on('popoverAllowClick', function(permissionChange) {
#             trackEvents('User','PushSubscriptionDone', "used_cars",true);
#             console.log('New permission state:', permissionChange);
#           });
#
#           OneSignal.on('popoverShown', function(permissionChange) {
#             trackEvents('User','PushSubscriptionPopupAppear', "used_cars",true);
#             console.log('New permission state:', permissionChange);
#           });
#
#       });
#
#       (function() {
#           var header = new Headroom(document.querySelector("#header"), {
#               tolerance: 5,
#               offset : 10,
#               classes: {
#                 initial: "animated",
#                 pinned: "slideDown",
#                 unpinned: "slideUp",
#               }
#           });
#           header.init();
#       }());
#   </script>
#  </body>
# </html>

# %%
for link in soup1.find_all("a"):
    print("href: {}".format(link.get("href")))
# Out:
# href: #
# href: /ur/used-cars
# href: javascript:void(0)
# href: javascript:void(0)
# href: /saved-ads
# href: /
# href: /
# href: /used-cars/
# href: /used-cars/search/-/
# href: /used-cars/search/-/featured_1/?nf=true
# href: /used-cars/sell
# href: /used-cars/dealers/
# href: /used-cars/price-calculator/
# href: /used-cars/pakwheels-certified/
# href: /products/pakwheels-inspection
# href: /products/pakwheels-sell-it-for-me/
# href: /auction-sheet-verification/
# href: None
# href: /used-cars/karachi/24857
rer=utm_source%3Dpakwheels.com%26utm_medium%3Dweb-link%26utm_content%3Dfooter%26utm_campaign%3Dorganic-installs
# href: https://click.google-analytics.com/redirect?tid=UA-642162-19&url=https%3A%2F%2Fitunes.apple.com%2Fpk%2Fapp%2Fpakwheels%2Fid739776365%3Fmt%3D8&aid=com.pakwheels.www&idfa={idfa}&cs=pakwheels.com&cm=web-link&cn=organic-installs&cc=footer&hash=md5
# href: https://appgallery.huawei.com/#/app/C101437147
# href: /used-cars/toyota/33
# href: /used-cars/suzuki/32
# href: /used-cars/honda/14
# href: /used-cars/daihatsu/12
# href: /used-cars/mitsubishi/25
# href: /used-cars/nissan/26
# href: /used-cars/mercedes-benz/23
# href: /used-cars/hyundai/15
# href: /used-cars/bmw/8
# href: /used-cars/karachi/24857
# href: /used-cars/lahore/24858
# href: /used-cars/islamabad/24856
# href: /used-cars/rawalpindi/24831
# href: /used-cars/peshawar/24821
# href: /used-cars/faisalabad/24753
# href: /used-cars/multan/24810
# href: /used-cars/gujranwala/24763
# href: /used-cars/sialkot/24841
# href: /used-cars/
# href: /used-bikes/
# href: /new-cars/
# href: /accessories-spare-parts/search/-/buynow_1/
# href: /rides/
# href: https://www.pakwheels.com/forums/
# href: /autoshow
# href: /sitemap/
# href: /main/about_us
# href: /products/
# href: /products/advertise
# href: /products/feature_your_ad#how_to_pay
# href: /FAQ
# href: /accessories-spare-parts/refunds-returns-policy/
# href: http://pakeventures.simplicant.com/
# href: /main/contact_us
# href: /used-cars/jeep/72893
# href: /used-cars/japanese/65933
# href: /used-cars/imported/57428
# href: /used-cars/automatic/57336
# href: /used-cars/low-priced/328875
# href: /used-cars/4x4/107784
# href: /used-cars/660cc-cars/190519
# href: /used-cars/1000cc-cars/190769
# href: /used-cars/sedan/107775
# href: /used-cars/hatchback/107774
# href: /used-cars/suv/107776
# href: /used-cars/crossover/107782
# href: /used-cars/mini-van/107785
# href: /used-cars/double-cabin/266839
# href: /used-cars/compact-sedan/441106
# href: /used-cars/mpv/145760
# href: /used-cars/white/107804
# href: /used-cars/silver/107802
# href: /used-cars/black/107787
# href: /used-cars/grey/107794
# href: /used-cars/blue/107788
# href: /used-cars/red/107801
# href: /used-cars/green/107793
# href: /used-cars/gold/107792
# href: /used-cars/punjab/201902
# href: /used-cars/sindh/201932
# href: /used-cars/kpk/201917
# href: /used-cars/balochistan/201947
# href: /used-cars/azad-kashmir/201953
# href: /used-cars/federally-administered-tribal-areas/201951
# href: /used-cars/sell
# href: /used-bikes/sell
# href: /accessories-spare-parts/sell
# href: https://www.twitter.com/pakwheels
# href: https://www.facebook.com/pakwheels
# href: https://plus.google.com/117775652035228984610
# href: https://pinterest.com/pakwheels/
# href: https://instagram.com/pakwheels
# href: https://www.youtube.com/user/pakwheels
# href: /apps
# href: https://play.google.com/store/apps/details?id=com.pakwheels&referrer=utm_source%3Dpakwheels.com%26utm_medium%3Dweb-link%26utm_content%3Dfooter%26utm_campaign%3Dorganic-installs
# href: https://click.google-analytics.com/redirect?tid=UA-642162-19&url=https%3A%2F%2Fitunes.apple.com%2Fpk%2Fapp%2Fpakwheels%2Fid739776365%3Fmt%3D8&aid=com.pakwheels.www&idfa={idfa}&cs=pakwheels.com&cm=web-link&cn=organic-installs&cc=footer&hash=md5
# href: https://appgallery.huawei.com/#/app/C101437147
# href: /main/terms
# href: /privacy-policy

# %%
a_few_urls=["/honda-insight-2019-for-sale-in-karachi-6780916",
"/honda-insight-2019-for-sale-in-karachi-6780916",
"/suzuki-swift-2017-for-sale-in-karachi-6659429",
"/suzuki-swift-2017-for-sale-in-karachi-6659429"
"/lexus-rx-series-2018-for-sale-in-karachi-6789389"
"/lexus-rx-series-2018-for-sale-in-karachi-6789389"
"/suzuki-cultus-2010-for-sale-in-karachi-6715715"
"/suzuki-cultus-2010-for-sale-in-karachi-6715715"
"/honda-civic-2017-for-sale-in-karachi-6814508"
"/honda-civic-2017-for-sale-in-karachi-6814508"
"/honda-br-v-2020-for-sale-in-karachi-6826237"
"/honda-br-v-2020-for-sale-in-karachi-6826237"
"/mg-hs-2021-for-sale-in-karachi-6651024"]

# %%
import requests
html_content = requests.get("https://www.pakwheels.com/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909#scroll_car_info").text

# %%
soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en">
#  <head>
#   <style>
#    .async-hide { opacity: 0 !important}
#   </style>
#   <script>
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#         h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#         (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#     })(window,document.documentElement,'async-hide','dataLayer',4000,
#         {'GTM-MZCSH9L':true});
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#         ga('create', 'UA-642162-6', 'auto');
#         ga('require', 'GTM-MZCSH9L');
#         ga('send', 'pageview');
#   </script>
#   <script async="" defer="" src="https://apis.google.com/js/platform.js">
#   </script>
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <!-- Google Analytics Content Experiment code -->
#   <script>
#    function utmx_section(){}function utmx(){}(function(){var
# k='106672894-35',d=document,l=d.location,c=d.cookie;
# if(l.search.indexOf('utm_expid='+k)>0)return;
# function f(n){if(c){var i=c.indexOf(n+'=');if(i>-1){var j=c.
# indexOf(';',i);return escape(c.substring(i+n.length+1,j<0?c.
# length:j))}}}var x=f('__utmx'),xx=f('__utmxx'),h=l.hash;d.write(
# '<sc'+'ript src="'+'http'+(l.protocol=='https:'?'s://ssl':
# '://www')+'.google-analytics.com/ga_exp.js?'+'utmxkey='+k+
# '&utmx='+(x?x:'')+'&utmxx='+(xx?xx:'')+'&utmxtime='+new Date().
# valueOf()+(h?'&utmxhash='+escape(h.substr(1)):'')+
# '" charset="utf-8"><\/sc'+'ript>')})();
#   </script>
#   <script>
#    utmx('url','A/B');
#   </script>
#   <!-- End of Google Analytics Content Experiment code -->
#   <link as="style" href="https://wsa1.pakwheels.com/assets/desktop/application-9041d3700ad26d02c65a1e1386c84076.css" rel="preload"/>
#   <link href="https://wsa1.pakwheels.com/assets/desktop/application-9041d3700ad26d02c65a1e1386c84076.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link as="font" crossorigin="" href="https://wsa3.pakwheels.com/assets/Lato-Regular-35cf7e967cceb3804eaf9dccf8f1228b.woff2" rel="preload"/>
#   <link as="font" crossorigin="" href="https://wsa4.pakwheels.com/assets/Lato-Bold-a901503621ac1a177f5ef7b4c6e6671e.woff2" rel="preload"/>
#   <link as="style" href="https://wsa1.pakwheels.com/assets/desktop/fonts-woff2-7f9fe6d80cdb7f20cc2bd69fcc60ea59.css" onload="this.rel='stylesheet'" rel="preload"/>
#   <link as="style" href="https://wsa2.pakwheels.com/assets/fonts-base64-woff-9009644a9b2e88f0d021717f9b557f80.css" onload="this.rel='stylesheet'" rel="preload"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Pak eVentures" name="author"/>
#   <meta content="874489252431-6l96qm7o7q7udar6eujfp01slvi9s86h.apps.googleusercontent.com" name="google-signin-client_id"/>
#   <meta content="139280839547845" property="fb:app_id"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <meta content="pakwheels://used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" property="al:android:url"/>
#   <meta content="com.pakwheels" property="al:android:package"/>
#   <meta content="Pakwheels" property="al:android:app_name"/>
#   <link href="android-app://com.pakwheels/http/www.pakwheels.com/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" rel="alternate"/>
#   <meta content="pakwheels://used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" property="al:ios:url"/>
#   <meta content="739776365" property="al:ios:app_store_id"/>
#   <meta content="Pakwheels" property="al:ios:app_name"/>
#   <link href="ios-app://739776365/pakwheels/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" rel="alternate"/>
#   <title>
#    Suzuki Alto VXL AGS 2021 for sale in Vehari | PakWheels
#   </title>
#   <meta content="Suzuki Alto VXL AGS 2021 Used for sale in Vehari. Buy this 660 cc, Silver 63000 KM Driven, Automatic Car. Contact Seller Now!" name="description"/>
#   <meta content="suzuki alto 2021 for sale, suzuki alto 2021, suzuki alto 2021 vehari, 2021 suzuki alto, suzuki alto for sale, used suzuki alto 2021" name="keywords"/>
#   <link href="/ur/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" hreflang="ur" rel="alternate"/>
#   <link href="/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" hreflang="x-default" rel="alternate"/>
#   <link href="https://www.pakwheels.com/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" rel="canonical"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Suzuki Alto VXL AGS 2021 for sale in Vehari | PakWheels" property="og:title"/>
#   <meta content="Suzuki Alto VXL AGS 2021 Used for sale in Vehari. Buy this 660 cc, Silver 63000 KM Driven, Automatic Car. Contact Seller Now!" property="og:description"/>
#   <meta content="Pakwheels" property="og:site_name"/>
#   <meta content="https://cache3.pakwheels.com/ad_pictures/7487/suzuki-alto-vxl-2-2021-74876618.webp" property="og:image"/>
#   <meta content="https://www.pakwheels.com/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" property="og:url"/>
#   <meta content="product" name="twitter:card"/>
#   <meta content="Suzuki Alto VXL AGS 2021 for sale in Vehari | PakWheels" name="twitter:title"/>
#   <meta content="Suzuki Alto VXL AGS 2021 Used for sale in Vehari. Buy this 660 cc, Silver 63000 KM Driven, Automatic Car. Contact Seller Now!" name="twitter:description"/>
#   <meta content="@pakwheels" name="twitter:site"/>
#   <meta content="@pakwheels" name="twitter:creator"/>
#   <meta content="https://cache3.pakwheels.com/ad_pictures/7487/suzuki-alto-vxl-2-2021-74876618.webp" name="twitter:image"/>
#   <meta content="https://cache3.pakwheels.com/ad_pictures/7487/suzuki-alto-vxl-2-2021-74876618.webp" name="image_src"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="m5KmPG7Hs784A7ERFGVYgGHrzXd9kf+mU8c7Hzk2yP4=" name="csrf-token"/>
#   <link href="//wsa1.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//wsa2.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache1.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache2.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache3.pakwheels.com" rel="dns-prefetch"/>
#   <link href="//cache4.pakwheels.com" rel="dns-prefetch"/>
#   <link href="/android-chrome-192x192.jpg" rel="apple-touch-icon"/>
#   <link href="/android-chrome-192x192.jpg" rel="icon"/>
#   <link href="https://plus.google.com/117392751510646293237" rel="publisher"/>
#   <link href="https://www.pakwheels.com/favicon.ico?t=1475740228" rel="shortcut icon" type="image/ico"/>
#   <script src="https://wsa4.pakwheels.com/assets/classified/top_javascript-2c0f803c5be2a04b66127624de5683d8.js" type="text/javascript">
#   </script>
#   <script src="https://wsa3.pakwheels.com/assets/classified/show-1531e7c0aab2fa103e6d3660a8cbc6fe.js" type="text/javascript">
#   </script>
#   <script>
#    var googletag = googletag || {};
#       googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
#    user_type = 'Anonymous';
#   is_mobile = '0';
#   newsletter_subscriber = 'false';
#   logged_in=false;
#   hashed_email='';
#          car_listings=bike_listings=parts_listings='';
#   pw_language = 'English';
#   </script>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-MMJ3TS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-9BLB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script>
#    var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     $(window).load(function() {
#       var gads = document.createElement("script");
#       gads.async = true;
#       gads.type = "text/javascript";
#       var useSSL = "https:" == document.location.protocol;
#       gads.src = (useSSL ? "https:" : "http:") +
#               "//www.googletagservices.com/tag/js/gpt.js";
#       var node = document.getElementsByTagName("script")[0];
#       node.parentNode.insertBefore(gads, node);
#     });
#   </script>
#   <script>
#    slots_to_be_refreshed = [];
#     googletag.cmd.push(function() {
#
#       var slot0 = googletag.defineSlot('/1012037/PakWheels_UsedCars_AdDetailPage_970x250', [970, 250] , 'div-gpt-PakWheels_UsedCars_AdDetailPage_970x250').addService(googletag.pubads());
#
#       var slot1 = googletag.defineSlot('/1012037/PakWheels_Desktop_UsedCarAdDetail_300x600', [300, 600] , 'div-gpt-PakWheels_Desktop_UsedCarAdDetail_300x600').addService(googletag.pubads());
#
#       var slot2 = googletag.defineSlot('/1012037/PakWheels_UsedCars_AdDetail_BTF_468x60', [468, 60] , 'div-gpt-PakWheels_UsedCars_AdDetail_BTF_468x60').addService(googletag.pubads());
#
#       var slot3 = googletag.defineSlot('/1012037/PakWheels_TopRightBar_ATF_415x91', [415, 91] , 'div-gpt-PakWheels_TopRightBar_ATF_415x91').addService(googletag.pubads());
#
#       var slot4 = googletag.defineSlot('/1012037/PakWheels_DesktopWeb_TopStickyBanner_450x30', [450, 30] , 'div-gpt-PakWheels_DesktopWeb_TopStickyBanner_450x30').addService(googletag.pubads());
#       googletag.pubads().collapseEmptyDivs();
#       customTargetUnit();
#       // googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#
#     function customTargetUnit(){
#       googletag.pubads().setTargeting("city", ($('#dfp_city').length > 0 && $('#dfp_city').val()) ? $('#dfp_city').val() : "");
#       googletag.pubads().setTargeting("make", ($('#dfp_make').length > 0 && $('#dfp_make').val()) ? $('#dfp_make').val() : "");
#       googletag.pubads().setTargeting("model", ($('#dfp_model').length > 0 && $('#dfp_model').val()) ? $('#dfp_model').val() : "");
#     }
#   </script>
#  </head>
#  <body>
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "WebPage",
#   "description": "Suzuki Alto VXL AGS 2021  Used for sale  in Vehari. Buy this 660 cc, Silver 63000 KM Driven, Automatic Car. Contact Seller Now!",
#   "name": "Suzuki Alto VXL AGS 2021 for sale in Vehari",
#   "inLanguage": "en"
# }
#   </script>
#   <i class="ajax-search-loader search-loader-fixed">
#    <img alt="Pakwheels" src="https://wsa2.pakwheels.com/assets/ic_pakwheels_logo-5da88229484345f24ac496d90b23a83e.svg"/>
#   </i>
#   <div class="header clearfix header--fixed" id="header">
#    <div class="mini-nav clearfix">
#     <a class="pull-left btn-mini-app" data-target="#download_apps" data-toggle="modal" href="#" onclick="trackEvents('User', 'FromHeader - AppInstallClicked', 'Used Cars - Show');">
#      <i class="fa fa-mobile generic-red">
#      </i>
#      Download App via SMS
#     </a>
#     <div class="pull-left ml10" style="margin-top: -2px; margin-bottom: 2px;">
#      <div id="div-gpt-PakWheels_DesktopWeb_TopStickyBanner_450x30">
#       <script type="text/javascript">
#        googletag.cmd.push(function(){ googletag.display("div-gpt-PakWheels_DesktopWeb_TopStickyBanner_450x30"); });
#       </script>
#      </div>
#     </div>
#     <ul class="list-unstyled pull-right signin mt5" style="margin-right: -5px;">
#      <li class="urdu-img">
#       <a class="generic-red" href="/ur/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909" onclick="trackEvents('User','Language','Urdu');" trailing_slash="true">
#        <span>
#         اردو
#        </span>
#       </a>
#      </li>
#      <li>
#       <a data-target="#sign-up-popup" data-toggle="modal" href="javascript:void(0)" rel="nofollow">
#        Sign Up
#       </a>
#      </li>
#      <li>
#       <a data-target="#sign_in_pop_up" data-toggle="modal" href="javascript:void(0)" rel="nofollow">
#        Sign In
#       </a>
#      </li>
#      <li id="save-ads" style="display:none">
#       <a href="/saved-ads" id="saved-ads" onclick="trackEvents('SaveAd','ViewSaveAd','From - Header')" rel="nofollow">
#        <i class="fa fa-heart fa-large">
#        </i>
#        <span class="badge badge-important" id="saved-ads-count" style="display:none">
#         0
#        </span>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="main-nav clearfix">
#     <div class="navbar-header">
#      <a class="navbar-brand logo-white" href="/" loading="lazy" title="PakWheels.com">
#       <img alt="PakWheels.com" src="https://wsa1.pakwheels.com/assets/new-pw-logo-white-b8b4c00b25fde9cc8f514dc4947c266a.svg" title="PakWheels.com"/>
#      </a>
#      <a class="navbar-brand logo-blue" href="/" title="PakWheels.com">
#       <img alt="PakWheels.com" src="https://wsa3.pakwheels.com/assets/new-pw-logo-f3b51e30f3761934b0a70973db08c32f.svg" title="PakWheels.com"/>
#      </a>
#     </div>
#     <ul class="nav navbar-nav navbar-right">
#      <li class="active dropdown">
#       <a href="/used-cars/" title="Used Cars for sale in Pakistan">
#        Used Cars
#        <i class="fa fa-caret-down">
#        </i>
#       </a>
#       <ul class="dropdown-menu mega-navbar columns-4">
#        <li class="clearfix">
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/used-cars/search/-/" title="Used Cars Search">
#             <i class="fa fa-search">
#             </i>
#             <strong>
#              Find Used Cars for Sale
#             </strong>
#             <p>
#              Search from over 110k options
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/search/-/featured_1/?nf=true" onclick="trackEvents('CarSearch', 'From - SubTabs','Featured');" rel="nofollow" title="Featured Used Cars">
#             <i class="fa fa-star">
#             </i>
#             <strong>
#              Featured Used Cars
#             </strong>
#             <p>
#              View featured cars by PakWheels
#             </p>
#            </a>
#           </li>
#           <li>
#            <a class="sign-in-comp" href="/used-cars/sell" onclick="trackEvents('Navigation', 'SubTabs - SellYourCar','Used Cars');" title="Sell Cars in Pakistan">
#             <i class="fa fa-tag">
#             </i>
#             <strong>
#              Sell Your Car
#             </strong>
#             <p>
#              Post a free ad and sell your car quickly
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/dealers/" onclick="trackEvents('Dealers', 'From - Navigation');" title="Used Cars Dealers in Pakistan">
#             <i class="fa fa-book">
#             </i>
#             <strong>
#              Used Car Dealers
#             </strong>
#             <p>
#              Find used car dealers near your
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/price-calculator/" rel="nofollow" title="Car Price Valuation">
#             <i class="fa fa-bullseye">
#             </i>
#             <strong>
#              Price Calculator
#             </strong>
#             <p>
#              Calculate the market price of cars
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/used-cars/pakwheels-certified/" title="Cars with the PakWheels seal of approval">
#             <i class="fa fa-check-square-o">
#             </i>
#             <strong>
#              PakWheels Certified Cars
#             </strong>
#             <p>
#              Cars with the PakWheels seal of approval
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/products/pakwheels-inspection" onclick="trackEvents('CarSure', 'From - NavigationMenu','');" title="Get Your Car Inspected by PakWheels Experts | PakWheels">
#             <i class="fa fa-thumbs-o-up">
#             </i>
#             <strong>
#              PakWheels Car Inspection
#             </strong>
#             <p>
#              Car with detailed PakWheels Inspection reports
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/products/pakwheels-sell-it-for-me/" onclick="trackEvents('SellItForMe', ' View Product Page','From - NavigationMenu');" title="">
#             <i class="fa fa-thumbs-o-up">
#             </i>
#             <strong>
#              PakWheels Sell It For Me
#             </strong>
#             <p>
#              Let PakWheels sell your car hassle free for you
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/auction-sheet-verification/" title="Authentic Auction Sheets for your peace of mind">
#             <i class="fa fa-file-text">
#             </i>
#             <strong>
#              Auction Sheet Verification
#             </strong>
#             <p>
#              Authentic Auction Sheets for your peace of mind
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <i class="fa fa-map-marker" style="font-size: 16px">
#             </i>
#             <strong>
#              Popular Cities
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/karachi/24857" title="Used Cars for sale in Karachi">
#             <p class="city-name">
#              Karachi
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/lahore/24858" title="Used Cars for sale in Lahore">
#             <p class="city-name">
#              Lahore
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/islamabad/24856" title="Used Cars for sale in Islamabad">
#             <p class="city-name">
#              Islamabad
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/rawalpindi/24831" title="Used Cars for sale in Rawalpindi">
#             <p class="city-name">
#              Rawalpindi
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/peshawar/24821" title="Used Cars for sale in Peshawar">
#             <p class="city-name">
#              Peshawar
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/faisalabad/24753" title="Used Cars for sale in Faisalabad">
#             <p class="city-name">
#              Faisalabad
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/multan/24810" title="Used Cars for sale in Multan">
#             <p class="city-name">
#              Multan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/gujranwala/24763" title="Used Cars for sale in Gujranwala">
#             <p class="city-name">
#              Gujranwala
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg aria-hidden="true" class="svg-inline--fa fa-car fa-w-16" data-icon="car" data-prefix="fas" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M499.99 176h-59.87l-16.64-41.6C406.38 91.63 365.57 64 319.5 64h-127c-46.06 0-86.88 27.63-103.99 70.4L71.87 176H12.01C4.2 176-1.53 183.34.37 190.91l6 24C7.7 220.25 12.5 224 18.01 224h20.07C24.65 235.73 16 252.78 16 272v48c0 16.12 6.16 30.67 16 41.93V416c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-32h256v32c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-54.07c9.84-11.25 16-25.8 16-41.93v-48c0-19.22-8.65-36.27-22.07-48H494c5.51 0 10.31-3.75 11.64-9.09l6-24c1.89-7.57-3.84-14.91-11.65-14.91zm-352.06-17.83c7.29-18.22 24.94-30.17 44.57-30.17h127c19.63 0 37.28 11.95 44.57 30.17L384 208H128l19.93-49.83zM96 319.8c-19.2 0-32-12.76-32-31.9S76.8 256 96 256s48 28.71 48 47.85-28.8 15.95-48 15.95zm320 0c-19.2 0-48 3.19-48-15.95S396.8 256 416 256s32 12.76 32 31.9-12.8 31.9-32 31.9z" fill="currentColor">
#              </path>
#             </svg>
#             <strong>
#              Popular Models
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/toyota-corolla/688" title="Toyota Corolla Cars for sale in Pakistan">
#             <p class="city-name">
#              Toyota Corolla
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/honda-civic/642" title="Honda Civic Cars for sale in Pakistan">
#             <p class="city-name">
#              Honda Civic
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/honda-city/664" title="Honda City Cars for sale in Pakistan">
#             <p class="city-name">
#              Honda City
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/suzuki-cultus/660" title="Suzuki Cultus Cars for sale in Pakistan">
#             <p class="city-name">
#              Suzuki Cultus
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/suzuki-mehran/661" title="Suzuki Mehran Cars for sale in Pakistan">
#             <p class="city-name">
#              Suzuki Mehran
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/toyota-vitz/781" title="Toyota Vitz Cars for sale in Pakistan">
#             <p class="city-name">
#              Toyota Vitz
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/suzuki-alto/658" title="Suzuki Alto Cars for sale in Pakistan">
#             <p class="city-name">
#              Suzuki Alto
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-cars/toyota-prado/38678" title="Toyota Prado Cars for sale in Pakistan">
#             <p class="city-name">
#              Toyota Prado
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="/new-cars/" title="Research New Cars in Pakistan, Car Prices, Reviews and Comparisons">
#        New Cars
#        <i class="fa fa-caret-down">
#        </i>
#       </a>
#       <ul class="dropdown-menu mega-navbar columns-3">
#        <li class="clearfix">
#         <div class="col-md-4">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/new-cars/" title="Research New Cars in Pakistan, Car Prices, Reviews and Comparisons">
#             <i class="fa fa-search">
#             </i>
#             <strong>
#              Find New Cars
#             </strong>
#             <p>
#              See new cars in Pakistan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/compare/" title="Car Comparisons">
#             <i class="fa fa-columns">
#             </i>
#             <strong>
#              Car Comparisons
#             </strong>
#             <p>
#              Compare cars and find their differences
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/reviews/" title="Reviews">
#             <i class="fa fa-comments">
#             </i>
#             <strong>
#              Reviews
#             </strong>
#             <p>
#              Read reviews of all cars in Pakistan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/pricelist/" title="Car Prices in Pakistan">
#             <i class="fa fa-tags">
#             </i>
#             <strong>
#              Prices
#             </strong>
#             <p>
#              See prices of new cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/on-road-price" onclick="trackEvents('OnRoadPrice', 'From - Navigation','');" title="Get Instant On Road Price">
#             <i class="fa fa-road">
#             </i>
#             <strong>
#              On Road Price
#             </strong>
#             <p>
#              Calculate the total cost of new car
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/dealers/" onclick="trackEvents('Dealers', 'From - Navigation','new cars');" title="New Cars Dealers in Pakistan">
#             <i class="fa fa-book">
#             </i>
#             <strong>
#              New Car Dealers
#             </strong>
#             <p>
#              Find new car dealers
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-4">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg fill="none" height="17" viewbox="0 0 17 17" width="17" xmlns="http://www.w3.org/2000/svg">
#              <path d="M11.5782 6.09819C11.4327 5.6691 11.0255 5.36365 10.5455 5.36365H2.54545C2.06545 5.36365 1.66545 5.6691 1.51273 6.09819L0 10.4546V16.2727C0 16.6727 0.327273 17 0.727273 17H1.45455C1.85455 17 2.18182 16.6727 2.18182 16.2727V15.5455H10.9091V16.2727C10.9091 16.6727 11.2364 17 11.6364 17H12.3636C12.7636 17 13.0909 16.6727 13.0909 16.2727V10.4546L11.5782 6.09819ZM2.54545 13.3636C1.94182 13.3636 1.45455 12.8764 1.45455 12.2727C1.45455 11.6691 1.94182 11.1818 2.54545 11.1818C3.14909 11.1818 3.63636 11.6691 3.63636 12.2727C3.63636 12.8764 3.14909 13.3636 2.54545 13.3636ZM10.5455 13.3636C9.94182 13.3636 9.45455 12.8764 9.45455 12.2727C9.45455 11.6691 9.94182 11.1818 10.5455 11.1818C11.1491 11.1818 11.6364 11.6691 11.6364 12.2727C11.6364 12.8764 11.1491 13.3636 10.5455 13.3636ZM1.45455 9.72728L2.54545 6.45456H10.5455L11.6364 9.72728H1.45455Z" fill="#373737">
#              </path>
#              <path d="M11.6363 10.2273C14.3225 10.2273 16.5 8.04975 16.5 5.36364C16.5 2.67752 14.3225 0.5 11.6363 0.5C8.95023 0.5 6.77271 2.67752 6.77271 5.36364C6.77271 8.04975 8.95023 10.2273 11.6363 10.2273Z" fill="#373737" stroke="white">
#              </path>
#              <path d="M13.7879 5.03223L12.8481 5.99886L13.057 7.35214C13.057 7.40737 13.0309 7.49022 12.9787 7.51784C12.9526 7.54546 12.9265 7.54546 12.8743 7.54546C12.8481 7.54546 12.822 7.54546 12.7959 7.51784L11.6473 6.88263L10.4988 7.51784C10.4466 7.54546 10.3682 7.54546 10.316 7.49023C10.2638 7.46261 10.2377 7.37975 10.2377 7.32452L10.4466 5.97124L9.5068 5.00461C9.45459 4.94937 9.45459 4.89414 9.45459 4.81128C9.48069 4.75605 9.5329 4.70081 9.58511 4.70081L10.8642 4.50749L11.4385 3.26468C11.4907 3.15421 11.6996 3.15421 11.7518 3.26468L12.3261 4.50749L13.6052 4.70081C13.7344 4.70081 13.8833 4.93125 13.7879 5.03223Z" fill="white">
#              </path>
#             </svg>
#             <strong>
#              Popular Brands
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/suzuki/" onclick="trackEvents('NewCars','From - Header','Suzuki')" title="Suzuki Cars in Paksitan">
#             <p class="city-name">
#              Suzuki Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/toyota/" onclick="trackEvents('NewCars','From - Header','Toyota')" title="Toyota Cars in Paksitan">
#             <p class="city-name">
#              Toyota Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/honda/" onclick="trackEvents('NewCars','From - Header','Honda')" title="Honda Cars in Paksitan">
#             <p class="city-name">
#              Honda Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/kia/" onclick="trackEvents('NewCars','From - Header','KIA')" title="KIA Cars in Paksitan">
#             <p class="city-name">
#              KIA Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/hyundai/" onclick="trackEvents('NewCars','From - Header','Hyundai')" title="Hyundai Cars in Paksitan">
#             <p class="city-name">
#              Hyundai Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/changan/" onclick="trackEvents('NewCars','From - Header','Changan')" title="Changan Cars in Paksitan">
#             <p class="city-name">
#              Changan Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/mg/" onclick="trackEvents('NewCars','From - Header','MG')" title="MG Cars in Paksitan">
#             <p class="city-name">
#              MG Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/bmw/" onclick="trackEvents('NewCars','From - Header','BMW')" title="BMW Cars in Paksitan">
#             <p class="city-name">
#              BMW Cars
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/audi/" onclick="trackEvents('NewCars','From - Header','Audi')" title="Audi Cars in Paksitan">
#             <p class="city-name">
#              Audi Cars
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-4">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg aria-hidden="true" class="svg-inline--fa fa-car fa-w-16" data-icon="car" data-prefix="fas" focusable="false" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M499.99 176h-59.87l-16.64-41.6C406.38 91.63 365.57 64 319.5 64h-127c-46.06 0-86.88 27.63-103.99 70.4L71.87 176H12.01C4.2 176-1.53 183.34.37 190.91l6 24C7.7 220.25 12.5 224 18.01 224h20.07C24.65 235.73 16 252.78 16 272v48c0 16.12 6.16 30.67 16 41.93V416c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-32h256v32c0 17.67 14.33 32 32 32h32c17.67 0 32-14.33 32-32v-54.07c9.84-11.25 16-25.8 16-41.93v-48c0-19.22-8.65-36.27-22.07-48H494c5.51 0 10.31-3.75 11.64-9.09l6-24c1.89-7.57-3.84-14.91-11.65-14.91zm-352.06-17.83c7.29-18.22 24.94-30.17 44.57-30.17h127c19.63 0 37.28 11.95 44.57 30.17L384 208H128l19.93-49.83zM96 319.8c-19.2 0-32-12.76-32-31.9S76.8 256 96 256s48 28.71 48 47.85-28.8 15.95-48 15.95zm320 0c-19.2 0-48 3.19-48-15.95S396.8 256 416 256s32 12.76 32 31.9-12.8 31.9-32 31.9z" fill="currentColor">
#              </path>
#             </svg>
#             <strong>
#              Popular New Cars
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/honda/civic/" title="Honda Civic">
#             <p class="city-name">
#              Honda Civic
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/suzuki/alto/" title="Suzuki Alto">
#             <p class="city-name">
#              Suzuki Alto
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/suzuki/cultus/" title="Suzuki Cultus">
#             <p class="city-name">
#              Suzuki Cultus
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/honda/city/" title="Honda City">
#             <p class="city-name">
#              Honda City
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/toyota/corolla/" title="Toyota Corolla">
#             <p class="city-name">
#              Toyota Corolla
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/toyota/yaris/" title="Toyota Yaris">
#             <p class="city-name">
#              Toyota Yaris
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/changan/alsvin/" title="Changan Alsvin">
#             <p class="city-name">
#              Changan Alsvin
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/suzuki/wagon-r/" title="Suzuki Wagon R">
#             <p class="city-name">
#              Suzuki Wagon R
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-cars/kia/sportage/" title="KIA Sportage">
#             <p class="city-name">
#              KIA Sportage
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </li>
#       </ul>
#      </li>
#      <li class="dropdown">
#       <a href="/bikes/" title="Bikes for sale in Pakistan">
#        Bikes
#        <i class="fa fa-caret-down">
#        </i>
#       </a>
#       <ul class="dropdown-menu mega-navbar columns-2" style="width:850px;">
#        <li class="clearfix">
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/used-bikes/" title="Motorcycles for sale in Pakistan">
#             <i class="fa fa-search">
#             </i>
#             <strong>
#              Find Used Bikes
#             </strong>
#             <p>
#              Find your dream bike
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-bikes/search/-/" rel="nofollow" title="Used Bikes Listings">
#             <svg fill="none" height="25" viewbox="0 0 34 20" width="18" xmlns="http://www.w3.org/2000/svg">
#              <path d="M11.948 16.4966C12.3729 15.1189 12.4116 13.7799 11.9995 12.428C11.2656 10.0331 9.65622 8.52671 7.28715 7.80569C6.73351 7.63831 6.12836 7.57393 5.5361 7.54818C4.23568 7.50955 3.1284 6.98166 2.13699 6.22201C1.48035 5.71987 1.31297 4.98598 1.59623 4.25208C1.86661 3.53106 2.48463 3.11904 3.30865 3.11904C4.8537 3.11904 6.39875 3.11904 7.93092 3.11904C8.79357 3.11904 8.9867 3.31217 8.9867 4.14907C8.9867 4.26495 8.9867 4.36796 8.9867 4.49671C10.5833 4.57396 11.9352 5.37224 13.3901 5.81C13.5832 5.8615 13.7248 5.92588 13.8922 5.71987C15.9265 3.42805 18.5531 2.79716 21.3986 3.89157C
#              <path d="M0 14.3721C0.0257508 11.2434 2.49783 8.9516 5.43341 8.9001C8.42051 8.86147 10.9312 11.385 10.9441 14.3464C10.9441 17.3464 8.45913 19.8313 5.47204 19.8313C2.47208 19.8442 0 17.3721 0 14.3721ZM1.35192 14.3593C1.35192 16.6253 3.20597 18.4923 5.45917 18.4923C7.68661 18.4923 9.55354 16.6382 9.57929 14.3979C9.59217 12.1576 7.69948 10.2263 5.48492 10.252C3.07722 10.2778 1.39054 12.1576 1.35192 14.3593Z" fill="#373737">
#              </path>
#              <path d="M5.43371 17.2176C7.01944 17.2176 8.30492 15.9322 8.30492 14.3464C8.30492 12.7607 7.01944 11.4752 5.43371 11.4752C3.84798 11.4752 2.5625 12.7607 2.5625 14.3464C2.5625 15.9322 3.84798 17.2176 5.43371 17.2176Z" fill="#373737">
#              </path>
#             </svg>
#             <strong>
#              Used Bikes Listings
#             </strong>
#             <p>
#              Search from over 5000+ options
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/used-bikes/search/-/featured_1/" rel="nofollow" title="Featured Used Bikes">
#             <i class="fa fa-star">
#             </i>
#             <strong>
#              Featured Used Bikes
#             </strong>
#             <p>
#              Browse our featured bikes
#             </p>
#            </a>
#           </li>
#           <li>
#            <a class="sign-in-comp" href="/used-bikes/sell" onclick="trackEvents('Navigation', 'Tabs - SellYourBike','');" title="Sell Bikes in Pakistan">
#             <i class="fa fa-tag">
#             </i>
#             <strong>
#              Sell Your Bike
#             </strong>
#             <p>
#              Post a free ad and sell your bike quickly
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a href="/bikes/new-bikes/" title="Research New Bikes in Pakistan, Bike Prices, Reviews and Comparisons">
#             <i class="fa fa-search">
#             </i>
#             <strong>
#              Find New Bikes
#             </strong>
#             <p>
#              See new bikes in Pakistan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/compare/" title="Bike Comparisons">
#             <i class="fa fa-columns">
#             </i>
#             <strong>
#              Bike Comparisons
#             </strong>
#             <p>
#              Compare bikes and find their differences
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/reviews/" title="Bike Reviews">
#             <i class="fa fa-comments">
#             </i>
#             <strong>
#              Bike Reviews
#             </strong>
#             <p>
#              Read reviews of all bikes in Pakistan
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/new-bikes/pricelist/" title="Bike Prices in Pakistan">
#             <i class="fa fa-tags">
#             </i>
#             <strong>
#              New Bikes Prices
#             </strong>
#             <p>
#              See prices of new bikes
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg fill="none" height="25" viewbox="0 0 34 20" width="18" xmlns="http://www.w3.org/2000/svg">
#              <path d="M11.948 16.4966C12.3729 15.1189 12.4116 13.7799 11.9995 12.428C11.2656 10.0331 9.65622 8.52671 7.28715 7.80569C6.73351 7.63831 6.12836 7.57393 5.5361 7.54818C4.23568 7.50955 3.1284 6.98166 2.13699 6.22201C1.48035 5.71987 1.31297 4.98598 1.59623 4.25208C1.86661 3.53106 2.48463 3.11904 3.30865 3.11904C4.8537 3.11904 6.39875 3.11904 7.93092 3.11904C8.79357 3.11904 8.9867 3.31217 8.9867 4.14907C8.9867 4.26495 8.9867 4.36796 8.9867 4.49671C10.5833 4.57396 11.9352 5.37224 13.3901 5.81C13.5832 5.8615 13.7248 5.92588 13.8922 5.71987C15.9265 3.42805 18.5531 2.79716 21.3986
#              <path d="M0 14.3721C0.0257508 11.2434 2.49783 8.9516 5.43341 8.9001C8.42051 8.86147 10.9312 11.385 10.9441 14.3464C10.9441 17.3464 8.45913 19.8313 5.47204 19.8313C2.47208 19.8442 0 17.3721 0 14.3721ZM1.35192 14.3593C1.35192 16.6253 3.20597 18.4923 5.45917 18.4923C7.68661 18.4923 9.55354 16.6382 9.57929 14.3979C9.59217 12.1576 7.69948 10.2263 5.48492 10.252C3.07722 10.2778 1.39054 12.1576 1.35192 14.3593Z" fill="#373737">
#              </path>
#              <path d="M5.43371 17.2176C7.01944 17.2176 8.30492 15.9322 8.30492 14.3464C8.30492 12.7607 7.01944 11.4752 5.43371 11.4752C3.84798 11.4752 2.5625 12.7607 2.5625 14.3464C2.5625 15.9322 3.84798 17.2176 5.43371 17.2176Z" fill="#373737">
#              </path>
#             </svg>
#             <strong>
#              Popular New Bikes
#             </strong>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/honda/cg-125--2/" onclick="trackEvents('NewBike','From - Header','Honda CG 125')" title="Honda CG 125 Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Honda CG 125
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/yamaha/ybr-125/" onclick="trackEvents('NewBike','From - Header','Yamaha YBR 125')" title="Yamaha YBR 125 Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Yamaha YBR 125
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/honda/cd-70--3/" onclick="trackEvents('NewBike','From - Header','Honda CD 70')" title="Honda CD 70 Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Honda CD 70
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/suzuki/gd-110s/" onclick="trackEvents('NewBike','From - Header','Suzuki GD 110S')" title="Suzuki GD 110S Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Suzuki GD 110S
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/suzuki/gs-150/" onclick="trackEvents('NewBike','From - Header','Suzuki GS 150')" title="Suzuki GS 150 Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Suzuki GS 150
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/honda/pridor/" onclick="trackEvents('NewBike','From - Header','Honda Pridor')" title="Honda Pridor Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Honda Pridor
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/yamaha/ybr-125g/" onclick="trackEvents('NewBike','From - Header','Yamaha YBR 125G')" title="Yamaha YBR 125G Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Yamaha YBR 125G
#             </p>
#            </a>
#           </li>
#           <li>
#            <a href="/bikes/honda/cb-150f/" onclick="trackEvents('NewBike','From - Header','Honda CB 150F')" title="Honda CB 150F Price in Pakistan, Pictures, Specs &amp; Features">
#             <p class="city-name">
#              Honda CB 150F
#             </p>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="col-md-3">
#          <ul class="list-unstyled">
#           <li>
#            <a>
#             <svg fill="none" height="25" viewbox="0 0 34 20" width="18" xmlns="http://www.w3.org/2000/svg">
# ...
#            Automatic Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/low-priced/328875" title="Low Price Cars in Pakistan for Sale">
#            Low Priced Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/4x4/107784" title="4x4 Cars for sale in Pakistan - Four Wheel Cars">
#            4x4 Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/660cc-cars/190519" title="660cc Cars for Sale in Pakistan">
#            660cc Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/1000cc-cars/190769" title="1000cc Cars for Sale in Pakistan">
#            1000cc Cars
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3">
#         <ul class="nomargin footer-links list-unstyled" id="footer-body_type">
#          <li>
#           <h5>
#            Cars by Body Type
#           </h5>
#          </li>
#          <li>
#           <a href="/used-cars/sedan/107775" title="Sedan Cars for Sale">
#            Sedan
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/hatchback/107774" title="Hatchback Cars for Sale">
#            Hatchback
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/suv/107776" title="SUV Cars for Sale">
#            SUV
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/crossover/107782" title="Crossover Cars for Sale">
#            Crossover
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/mini-van/107785" title="Mini Van Cars for Sale">
#            Mini Van
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/double-cabin/266839" title="Double Cabin Cars for Sale">
#            Double Cabin
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/compact-sedan/441106" title="Compact sedan Cars for Sale">
#            Compact sedan
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/mpv/145760" title="MPV Cars for Sale">
#            MPV
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3">
#         <ul class="nomargin footer-links list-unstyled" id="footer-color">
#          <li>
#           <h5>
#            Cars by Color
#           </h5>
#          </li>
#          <li>
#           <a href="/used-cars/white/107804" title="White Cars for Sale">
#            White Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/silver/107802" title="Silver Cars for Sale">
#            Silver Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/black/107787" title="Black Cars for Sale">
#            Black Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/grey/107794" title="Grey Cars for Sale">
#            Grey Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/blue/107788" title="Blue Cars for Sale">
#            Blue Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/red/107801" title="Red Cars for Sale">
#            Red Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/green/107793" title="Green Cars for Sale">
#            Green Cars
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/gold/107792" title="Gold Cars for Sale">
#            Gold Cars
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-3">
#         <ul class="nomargin footer-links list-unstyled" id="footer-province">
#          <li>
#           <h5>
#            Cars by Province
#           </h5>
#          </li>
#          <li>
#           <a href="/used-cars/punjab/201902" title="Punjab Cars for Sale">
#            Cars in Punjab
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/sindh/201932" title="Sindh Cars for Sale">
#            Cars in Sindh
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/kpk/201917" title="KPK Cars for Sale">
#            Cars in KPK
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/balochistan/201947" title="Balochistan Cars for Sale">
#            Cars in Balochistan
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/azad-kashmir/201953" title="Azad Kashmir Cars for Sale">
#            Cars in Azad Kashmir
#           </a>
#          </li>
#          <li>
#           <a href="/used-cars/federally-administered-tribal-areas/201951" title="Federally Administered Tribal Areas Cars for Sale">
#            Cars in Federally Administered Tribal Areas
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="col-md-3">
#       <div class="row">
#        <div class="col-md-12" style="padding-left: 0px;">
#         <ul class="nomargin footer-links list-unstyled">
#          <li>
#           <h5>
#            Sell On PakWheels
#           </h5>
#          </li>
#          <li>
#           <a class="sign-in-comp" href="/used-cars/sell" id="foot-sell-car" onclick="trackEvents('UsedCars', 'Add Car', 'From - Footer')" title="Sell Your Car in Pakistan">
#            Sell Your Car
#           </a>
#          </li>
#          <li>
#           <a class="sign-in-comp" href="/used-bikes/sell" id="foot-sell-bike" onclick="trackEvents('UsedBikes','Sellform','From - Footer')" title="Sell Your Bike in Pakistan">
#            Sell Your Bike
#           </a>
#          </li>
#          <li>
#           <a class="sign-in-comp" href="/accessories-spare-parts/sell" id="foot-sell-accessory" onclick="trackEvents('Accessories','Sell','From - Footer')" title="Sell Autoparts &amp; Accessories in Pakistan">
#            Sell Accessory
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="row">
#        <form class="form-horizontal newsletter-subscription" id="subscribe_newsletter">
#         <h5>
#          Subscribe to our Newsletter
#         </h5>
#         <div id="newsletter-message" style="display:none; font-size: 14px; color: #999999;">
#         </div>
#         <div class="form-fields">
#          <input id="email" name="email" placeholder="name@email.com" style="width: 100%; font-family: arial;" type="text"/>
#          <button class="btn btn-success btn-xs" type="submit">
#           Subscribe
#          </button>
#          <div class="error-message" style="color:red;">
#          </div>
#         </div>
#        </form>
#        <div class="mb30 footer-social clearfix">
#         <h5>
#          Follow Us
#         </h5>
#         <ul class="list-unstyled list-inline networks primary-lang">
#          <li>
#           <a class="twitter" href="https://www.twitter.com/pakwheels" rel="nofollow" target="_blank" title="Follow Us On Twitter">
#            <i class="fa fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="facebook" href="https://www.facebook.com/pakwheels" rel="nofollow" target="_blank" title="Follow Us On Facebook">
#            <i class="fa fa-facebook">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="googleplus" href="https://plus.google.com/117775652035228984610" rel="me" target="_blank" title="Follow Us On Google Plus">
#            <i class="fa fa-google-plus">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="pinterest" href="https://pinterest.com/pakwheels/" rel="nofollow" target="_blank" title="Follow Us On Pinterest">
#            <i class="fa fa-pinterest">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="instagram" href="https://instagram.com/pakwheels" rel="nofollow" target="_blank" title="Follow Us On Instagram">
#            <i class="fa fa-instagram">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a class="youtube" href="https://www.youtube.com/user/pakwheels" rel="me" target="_blank" title="Follow Us On Youtube">
#            <i class="fa fa-youtube">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div>
#         <h5>
#          <a class="generic-white" href="/apps">
#           Download Mobile Apps
#          </a>
#         </h5>
#         <a href="https://play.google.com/store/apps/details?id=com.pakwheels&amp;referrer=utm_source%3Dpakwheels.com%26utm_medium%3Dweb-link%26utm_content%3Dfooter%26utm_campaign%3Dorganic-installs" target="_blank" title="PakWheels Android App">
#          <img alt="Google-play-badge" height="40" loading="lazy" src="https://wsa4.pakwheels.com/assets/google-play-badge-f4bed6cbd8a3a1be7c79377c4441447a.svg"/>
#         </a>
#         <a href="https://click.google-analytics.com/redirect?tid=UA-642162-19&amp;url=https%3A%2F%2Fitunes.apple.com%2Fpk%2Fapp%2Fpakwheels%2Fid739776365%3Fmt%3D8&amp;aid=com.pakwheels.www&amp;idfa={idfa}&amp;cs=pakwheels.com&amp;cm=web-link&amp;cn=organic-installs&amp;cc=footer&amp;hash=md5" target="_blank" title="PakWheels iOS App">
#          <img alt="App-store-badge" height="40" loading="lazy" src="https://wsa1.pakwheels.com/assets/app-store-badge-4d05ff70e5546f31e3891739ea40abad.svg"/>
#         </a>
#         <a href="https://appgallery.huawei.com/#/app/C101437147" target="_blank" title="PakWheels Android App">
#          <img alt="Huawei-store-badge" height="40" loading="lazy" src="https://wsa4.pakwheels.com/assets/huawei-store-badge-7ad06f9ffe74b644d49c6221af98f5b3.svg"/>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <hr class="dark"/>
#     <div class="copyright footer-links mt30">
#      Copyright &amp;copy 2003 - 2022 PakWheels (Pvt) Ltd. - All Rights Reserved.
#      <br/>
#      <a href="/main/terms" rel="nofollow" title="Terms of Service">
#       Terms of Service
#      </a>
#      |
#      <a href="/privacy-policy" rel="nofollow" title="Privacy Policy">
#       Privacy Policy
#      </a>
#     </div>
#     <p class="copyright mt5">
#      Reproduction of material from any PakWheels.com pages without permission is strictly prohibited.
#     </p>
#    </div>
#   </div>
#   <div data-auto_select="false" data-cancel_on_tap_outside="false" data-client_id="874489252431-6l96qm7o7q7udar6eujfp01slvi9s86h.apps.googleusercontent.com" data-context="use" data-login_uri="https://www.pakwheels.com/confirm-google-login" data-nonce="" id="g_id_onload">
#   </div>
#   <script>
#    $(document).ready(function(){
#       $('#form_alert').on('ajax:success',function(e, data, status, xhr){
#         if(data.alert_added==true){
#           $('.alert-success#success_div').append(data.success).show();
#         }else {
#           $('.alert-danger#error_div').append(data.error).show();
#         }
#         $('.alert-form-container').fadeOut();
#         $(window).scrollTop(0);
#       }).on('ajax:error',function(e, xhr, status, error){
#         $('.alert-form-container').fadeOut();
#         $('.alert-danger#error_div').append("Sorry your alert could not be added. Please try again later").show();
#         $(window).scrollTop(0);
#       });
#     });
#   </script>
#   <script>
#    $('.nav-dropdown-menu').on('mouseover', function() {
#         $(this).parent().addClass('open');
#       });
#       $('.nav-dropdown-menu').on('mouseout', function() {
#         $(this).parent().removeClass('open');
#       });
#       $(document).ready(function (){ $('#navbar_static_top').attr('data-offset-top', $('.advertisement').innerHeight() + $('.header').innerHeight());
#
#         $("#user-menu,#lang-menu").click(function(e){
#           $(this).toggleClass("open");
#             e.stopPropagation();
#         });
#
#       });
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
#     (function(d, s, id) {
#       var js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return;
#       js = d.createElement(s); js.id = id;
#       js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.8&appId=139280839547845";
#       fjs.parentNode.insertBefore(js, fjs);
#       }(document, 'script', 'facebook-jssdk'));
#
# //]]>
#   </script>
#   <script>
#    var om_load_jquery = false;
#   </script>
#   <div id="om-dxawge5rc65nrwtv-holder">
#   </div>
#   <script>
#    $(window).load(function(){
#           var dxawge5rc65nrwtv,dxawge5rc65nrwtv_poll=function(){var r=0;return function(n,l){clearInterval(r),r=setInterval(n,l)}}();!function(e,t,n){if(e.getElementById(n)){dxawge5rc65nrwtv_poll(function(){if(window['om_loaded']){if(!dxawge5rc65nrwtv){dxawge5rc65nrwtv=new OptinMonsterApp();return dxawge5rc65nrwtv.init({u:"10331.222818",staging:0,dev:0});}}},25);return;}var d=false,o=e.createElement(t);o.id=n, o.async=true, o.src="//a.optinmonster.com/app/js/api.min.js",o.onload=o.onreadystatechange=function(){if(!d){if(!this.readyState||this.readyState==="loaded"||this.readyState==="complete"){try{d=om_loaded=true;dxawge5rc65nrwtv=new OptinMonsterApp();dxawge5rc65nrwtv.init({u:"10331.222818",staging:0,dev:0});o.onload=o.onreadystatechange=null;}catch(t){}}}};(document.getElementsByTagName("head")[0]||document.documentElement).appendChild(o)}(document,"script","omapi-script");
#         });
#   </script>
#   <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#   <script>
#    var OneSignal = window.OneSignal || [];
#       OneSignal.push(["init", {
#         appId: "2cca5b5e-e246-46f7-9a26-f638f0d42a03",
#         safari_web_id: "web.onesignal.auto.5e769637-3ad0-4829-bde6-e4b31d264ae2",
#         autoRegister: false, /* Set to true to automatically prompt visitors */
#         httpPermissionRequest: {
#             enable: true
#         },
#         notifyButton: {
#           enable: false /* Set to false to hide */
#         },
#         promptOptions: {
#             siteName: 'OneSignal Documentation',
#             actionMessage: "Subscribe to our push notification for the latest news & Updates",
#             acceptButtonText: "ALLOW",
#             cancelButtonText: "NO THANKS"
#         },
#         path: '/OneSignalDesktop/',
#       }]);
#       OneSignal.push(function() {
#           OneSignal.isPushNotificationsEnabled(function(isEnabled) {
#               if (isEnabled)
#                   console.log("Push notifications are enabled!");
#               else{
#                 OneSignal.push(function() {
#                   OneSignal.showHttpPrompt();
#                 });
#               }
#           });
#
#           OneSignal.on('subscriptionChange', function (isSubscribed) {
#               console.log("The user's subscription status has change, isSubscribed:", isSubscribed);
#               if (isSubscribed)
#               {
#                 trackEvents('User','From-browser PushSubscriptionDone', "used_cars",true);
#               }else{
#                  trackEvents('User','From-browser PushSubscriptionClosed', "used_cars",true);
#               }
#               OneSignal.getUserId( function(userId) {
#                   console.log("OneSignal User ID:", userId);
#                   // Make a POST call to GA with the subscription data and userId aka playerId
#                   // trackEvents('User','Subscription_Change', '',true);
#                   // ga('send', 'event', 'Subscription_Change', isSubscribed, userId);
#               });
#           });
#
#           OneSignal.on('popoverCancelClick', function(permissionChange) {
#             trackEvents('User','PushSubscriptionClosed', "used_cars",true);
#             console.log('New permission state:', permissionChange);
#           });
#           OneSignal.on('popoverAllowClick', function(permissionChange) {
#             trackEvents('User','PushSubscriptionDone', "used_cars",true);
#             console.log('New permission state:', permissionChange);
#           });
#
#           OneSignal.on('popoverShown', function(permissionChange) {
#             trackEvents('User','PushSubscriptionPopupAppear', "used_cars",true);
#             console.log('New permission state:', permissionChange);
#           });
#
#       });
#
#       (function() {
#           var header = new Headroom(document.querySelector("#header"), {
#               tolerance: 5,
#               offset : 10,
#               classes: {
#                 initial: "animated",
#                 pinned: "slideDown",
#                 unpinned: "slideUp",
#               }
#           });
#           header.init();
#       }());
#   </script>
#  </body>
# </html>

# %%
print(soup.title)
# Out:
# <title>Suzuki Alto VXL AGS 2021 for sale in Vehari | PakWheels</title>

# %%
soup.title.text
# Out:
# 'Suzuki Alto VXL AGS 2021 for sale in Vehari | PakWheels'

# %%
for link in soup.find_all("a"):
    print("Inner Text: {}".format(link.text))
    print("Title: {}".format(link.get("title")))
    print("href: {}".format(link.get("href")))
# Out:
# Inner Text:  Download App via SMS
# Title: None
# href: #
# Inner Text: اردو
# Title: None
# href: /ur/used-cars/suzuki-alto-2021-for-sale-in-vehari-6816909
# Inner Text: Sign Up
# Title: None
# href: javascript:void(0)
# Inner Text: Sign In
# Title: None
# href: javascript:void(0)
# Inner Text: 0
# Title: None
# href: /saved-ads
# Inner Text:
# Title: PakWheels.com
# href: /
# Inner Text:
# Title: PakWheels.com
# href: /
# Inner Text:
#             Used Cars
#
# Title: Used Cars for sale in Pakistan
# href: /used-cars/
# Inner Text:
#
# Find Used Cars for Sale
# Search from over 110k options
#
# Title: Used Cars Search
# href: /used-cars/search/-/
# Inner Text:
#
# Featured Used Cars
# View featured cars by PakWheels
#
# Title: Featured Used Cars
# href: /used-cars/search/-/featured_1/?nf=true
# Inner Text:
#
# Sell Your Car
# Post a free ad and sell your car quickly
#
# Title: Sell Cars in Pakistan
# href: /used-cars/sell
# Inner Text:
#
# Used Car Dealers
# Find used car dealers near your
#
# Title: Used Cars Dealers in Pakistan
# href: /used-cars/dealers/
# Inner Text:
#
# Price Calculator
# Calculate the market price of cars
#
# Title: Car Price Valuation
# href: /used-cars/price-calculator/
# Inner Text:
#
# PakWheels Certified Cars
# Cars with the PakWheels seal of approval
#
# Title: Cars with the PakWheels seal of approval
# href: /used-cars/pakwheels-certified/
# Inner Text:
#
# PakWheels Car Inspection
# Car with detailed PakWheels Inspection reports
#
# Title: Get Your Car Inspected by PakWheels Experts | PakWheels
# href: /products/pakwheels-inspection
# Inner Text:
#
# PakWheels Sell It For Me
# Let PakWheels sell your car hassle free for you
#
# Title:
# href: /products/pakwheels-sell-it-for-me/
# Inner Text:
#
# Auction Sheet Verification
# Authentic Auction Sheets for your peace of mind
#
# Title: Authentic Auction Sheets for your peace of mind
# href: /auction-sheet-verification/
# Inner Text:
#
# Popular Cities
#
# Title: None
# href: None
# Inner Text:
# Karachi
#
# Title: Used Cars for sale in Karachi
# href: /used-cars/karachi/24857
# Inner Text:
# Lahore
#
# Title: Used Cars for sale in Lahore
# href: /used-cars/lahore/24858
# Inner Text:
# Islamabad
#
# Title: Used Cars for sale in Islamabad
# href: /used-cars/islamabad/24856
# Inner Text:
# Rawalpindi
#
# Title: Used Cars for sale in Rawalpindi
# href: /used-cars/rawalpindi/24831
# Inner Text:
# Peshawar
#
# Title: Used Cars for sale in Peshawar
# href: /used-cars/peshawar/24821
# Inner Text:
# Faisalabad
#
# Title: Used Cars for sale in Faisalabad
# href: /used-cars/faisalabad/24753
# Inner Text:
# Multan
#
# Title: Used Cars for sale in Multan
# href: /used-cars/multan/24810
# Inner Text:
# Gujranwala
#
# Title: Used Cars for sale in Gujranwala
# href: /used-cars/gujranwala/24763
# Inner Text:
#
# Popular Models
#
# Title: None
# href: None
# Inner Text:
# Toyota Corolla
#
# Title: Toyota Corolla Cars for sale in Pakistan
# href: /used-cars/toyota-corolla/688
# Inner Text:
# Honda Civic
#
# Title: Honda Civic Cars for sale in Pakistan
# href: /used-cars/honda-civic/642
# Inner Text:
# Honda City
#
# Title: Honda City Cars for sale in Pakistan
# href: /used-cars/honda-city/664
# Inner Text:
# Suzuki Cultus
#
# Title: Suzuki Cultus Cars for sale in Pakistan
# href: /used-cars/suzuki-cultus/660
# Inner Text:
# Suzuki Mehran
#
# Title: Suzuki Mehran Cars for sale in Pakistan
# href: /used-cars/suzuki-mehran/661
# Inner Text:
# Toyota Vitz
#
# Title: Toyota Vitz Cars for sale in Pakistan
# href: /used-cars/toyota-vitz/781
# Inner Text:
# Suzuki Alto
#
# Title: Suzuki Alto Cars for sale in Pakistan
# href: /used-cars/suzuki-alto/658
# Inner Text:
# Toyota Prado
#
# Title: Toyota Prado Cars for sale in Pakistan
# href: /used-cars/toyota-prado/38678
# Inner Text:
#             New Cars
#
# Title: Research New Cars in Pakistan, Car Prices, Reviews and Comparisons
# href: /new-cars/
# Inner Text:
#
# Find New Cars
# See new cars in Pakistan
#
# Title: Research New Cars in Pakistan, Car Prices, Reviews and Comparisons
# href: /new-cars/
# Inner Text:
#
# Car Comparisons
# Compare cars and find their differences
#
# Title: Car Comparisons
# href: /new-cars/compare/
# Inner Text:
#
# Reviews
# Read reviews of all cars in Pakistan
#
# Title: Reviews
# href: /new-cars/reviews/
# Inner Text:
#
# Prices
# See prices of new cars
#
# Title: Car Prices in Pakistan
# href: /new-cars/pricelist/
# Inner Text:
#
# On Road Price
# Calculate the total cost of new car
#
# Title: Get Instant On Road Price
# href: /new-cars/on-road-price
# Inner Text:
#
# New Car Dealers
# Find new car dealers
#
# Title: New Cars Dealers in Pakistan
# href: /new-cars/dealers/
# Inner Text:
#
# Popular Brands
#
# Title: None
# href: None
# Inner Text:
# Suzuki Cars
#
# Title: Suzuki Cars in Paksitan
# href: /new-cars/suzuki/
# Inner Text:
# Toyota Cars
#
# Title: Toyota Cars in Paksitan
# href: /new-cars/toyota/
# Inner Text:
# Honda Cars
#
# Title: Honda Cars in Paksitan
# href: /new-cars/honda/
# Inner Text:
# KIA Cars
#
# Title: KIA Cars in Paksitan
# href: /new-cars/kia/
# Inner Text:
# Hyundai Cars
#
# Title: Hyundai Cars in Paksitan
# href: /new-cars/hyundai/
# Inner Text:
# Changan Cars
#
# Title: Changan Cars in Paksitan
# href: /new-cars/changan/
# Inner Text:
# MG Cars
#
# Title: MG Cars in Paksitan
# href: /new-cars/mg/
# Inner Text:
# BMW Cars
#
# Title: BMW Cars in Paksitan
# href: /new-cars/bmw/
# Inner Text:
# Audi Cars
#
# Title: Audi Cars in Paksitan
# href: /new-cars/audi/
# Inner Text:
#
# Popular New Cars
#
# Title: None
# href: None
# Inner Text:
# Honda Civic
#
# Title: Honda Civic
# href: /new-cars/honda/civic/
# Inner Text:
# Suzuki Alto
#
# Title: Suzuki Alto
# href: /new-cars/suzuki/alto/
# Inner Text:
# Suzuki Cultus
#
# Title: Suzuki Cultus
# href: /new-cars/suzuki/cultus/
# Inner Text:
# Honda City
#
# Title: Honda City
# href: /new-cars/honda/city/
# Inner Text:
# Toyota Corolla
#
# Title: Toyota Corolla
# href: /new-cars/toyota/corolla/
# Inner Text:
# Toyota Yaris
#
# Title: Toyota Yaris
# href: /new-cars/toyota/yaris/
# Inner Text:
# Changan Alsvin
#
# Title: Changan Alsvin
# href: /new-cars/changan/alsvin/
# Inner Text:
# Suzuki Wagon R
#
# Title: Suzuki Wagon R
# href: /new-cars/suzuki/wagon-r/
# Inner Text:
# KIA Sportage
#
# Title: KIA Sportage
# href: /new-cars/kia/sportage/
# Inner Text:
#             Bikes
#
# Title: Bikes for sale in Pakistan
# href: /bikes/
# Inner Text:
#
# Find Used Bikes
# Find your dream bike
#
# Title: Motorcycles for sale in Pakistan
# href: /used-bikes/
# Inner Text:
#
# Used Bikes Listings
# Search from over 5000+ options
#
# Title: Used Bikes Listings
# href: /used-bikes/search/-/
# Inner Text:
#
# Featured Used Bikes
# Browse our featured bikes
#
# Title: Featured Used Bikes
# href: /used-bikes/search/-/featured_1/
# Inner Text:
#
# Sell Your Bike
# Post a free ad and sell your bike quickly
#
# Title: Sell Bikes in Pakistan
# href: /used-bikes/sell
# Inner Text:
#
# Find New Bikes
# See new bikes in Pakistan
#
# Title: Research New Bikes in Pakistan, Bike Prices, Reviews and Comparisons
# href: /bikes/new-bikes/
# Inner Text:
#
# Bike Comparisons
# Compare bikes and find their differences
#
# Title: Bike Comparisons
# href: /bikes/compare/
# Inner Text:
#
# Bike Reviews
# Read reviews of all bikes in Pakistan
#
# Title: Bike Reviews
# href: /bikes/reviews/
# Inner Text:
#
# New Bikes Prices
# See prices of new bikes
#
# Title: Bike Prices in Pakistan
# href: /new-bikes/pricelist/
# Inner Text:
#
# Popular New Bikes
#
# Title: None
# href: None
# Inner Text:
# Honda CG 125
#
# Title: Honda CG 125 Price in Pakistan, Pictures, Specs & Features
# href: /bikes/honda/cg-125--2/
# Inner Text:
# Yamaha YBR 125
#
# Title: Yamaha YBR 125 Price in Pakistan, Pictures, Specs & Features
# href: /bikes/yamaha/ybr-125/
# Inner Text:
# Honda CD 70
#
# Title: Honda CD 70 Price in Pakistan, Pictures, Specs & Features
# href: /bikes/honda/cd-70--3/
# Inner Text:
# Suzuki GD 110S
#
# Title: Suzuki GD 110S Price in Pakistan, Pictures, Specs & Features
# href: /bikes/suzuki/gd-110s/
# Inner Text:
# Suzuki GS 150
#
# Title: Suzuki GS 150 Price in Pakistan, Pictures, Specs & Features
# href: /bikes/suzuki/gs-150/
# Inner Text:
# Honda Pridor
#
# Title: Honda Pridor Price in Pakistan, Pictures, Specs & Features
# href: /bikes/honda/pridor/
# Inner Text:
# Yamaha YBR 125G
#
# Title: Yamaha YBR 125G Price in Pakistan, Pictures, Specs & Features
# href: /bikes/yamaha/ybr-125g/
# Inner Text:
# Honda CB 150F
#
# Title: Honda CB 150F Price in Pakistan, Pictures, Specs & Features
# href: /bikes/honda/cb-150f/
# Inner Text:
#
# Popular Used Bikes
#
# Title: None
# href: None
# Inner Text:
# Honda CG 125
#
# Title: Honda CG 125 for sale in Pakistan
# href: /used-bikes/honda-cg-125/56649
# Inner Text:
# Honda CD 70
#
# Title: Honda CD 70 for sale in Pakistan
# href: /used-bikes/honda-cd-70/56630
# Inner Text:
# Yamaha YBR 125
#
# Title: Yamaha YBR 125 for sale in Pakistan
# href: /used-bikes/yamaha-ybr-125/58641
# Inner Text:
# Suzuki GS 150
#
# Title: Suzuki GS 150 for sale in Pakistan
# href: /used-bikes/suzuki-gs-150/56555
# Inner Text:
# Honda CB 125F
#
# Title: Honda CB 125F for sale in Pakistan
# href: /used-bikes/honda-cb-125f/369803
# Inner Text:
# Yamaha YBR 125G
#
# Title: Yamaha YBR 125G for sale in Pakistan
# href: /used-bikes/yamaha-ybr-125g/61790
# Inner Text:
# Honda Pridor
#
# Title: Honda Pridor for sale in Pakistan
# href: /used-bikes/honda-pridor/211065
# Inner Text:
# Hi Speed Infinity 150
#
# Title: Hi Speed Infinity 150 for sale in Pakistan
# href: /used-bikes/hi-speed-infinity-150/210064
# Inner Text:
#             Auto Store
#
# Title: Parts & Accessories
# href: /accessories-spare-parts/
# Inner Text:
#
# PakWheels Autostore
# Buy Auto Parts & Accessories directly from PakWheels
#
# Title: Buy Car Parts in Pakistan
# href: /accessories-spare-parts/search/-/buynow_1/
# Inner Text:
#
# Find Auto Parts
# Find auto parts for your car
#
# Title: Search Accessories
# href: /accessories-spare-parts/search/-/
# Inner Text:
#
# Sell Car Parts
# Post a free ad and sell your car parts quickly
#
# Title: Sell Your Accessory
# href: /accessories-spare-parts/sell
# Inner Text: Videos
# Title: Get the latest video reviews, tips and news
# href: /videos/
# Inner Text: Forums
# Title: Discuss Automobiles in Pakistan
# href: https://www.pakwheels.com/forums/
# Inner Text: Blog
# Title: Read Pakistan Automotive News & Blog
# href: /blog/
# Inner Text:
#             More
#
# Title: None
# href: javascript:void
# Inner Text:
#
# Cool Rides
# Member Rides Cars & Bikes
#
# Title: Member Rides Cars & Bikes
# href: /rides/
# Inner Text:
#
# Car Import
# Import your favourite Car
#
# Title: Car Import in Pakistan
# href: /car-import/
# Inner Text:
#
# Car Insurance
# Get car insurance quote
#
# Title: Car Insurance in Pakistan
# href: /car-insurance/
# Inner Text:
#
# Car Finance
# Compare plans and apply for car loan
#
# Title: Car Financing in Pakistan
# href: /car-finance/
# Inner Text:
#
# MTMIS Pakistan
# Online Vehicle Verification
#
# Title: Online Vehicle Verification
# href: /mtmis-online-vehicle-verification/
# Inner Text:
#
# DLIMS Pakistan
# Driving License Verification System
#
# Title: DLIMS - Driving License Verification Pakistan
# href: /dlims-driving-license-verification/
# Inner Text:
#
# Current Fuel Prices
# Check latest Petrol, Diesel and CNG Price
#
# Title: Petrol, Diesel & CNG Prices in Pakistan today
# href: /petroleum-prices-in-pakistan
# Inner Text:
#                 Post an Ad
#
# Title: Post an Ad
# href: /used-cars/sell
# Inner Text:
# Sell Your Car
#
# Title: Sell Cars in Pakistan
# href: /used-cars/sell
# Inner Text:
# Sell Your Bike
#
# Title: Sell Bikes in Pakistan
# href: /used-bikes/sell
# Inner Text:
# Sell Accessory
#
# Title: Sell Your Accessory
# href: /accessories-spare-parts/sell
# Inner Text:
# Title: None
# href: https://play.google.com/store/apps/details?id=com.pakwheels&referrer=utm_source%3Dpakwheels.com%26utm_medium%3Dmobile-web-link%26utm_content%3Dinterstitial%26utm_campaign%3Dorganic-installs
# Inner Text:
# Title: None
# href: https://click.google-analytics.com/redirect?tid=UA-642162-19&url=https%3A%2F%2Fitunes.apple.com%2Fpk%2Fapp%2Fpakwheels%2Fid739776365%3Fmt%3D8&aid=com.pakwheels.www&idfa={idfa}&cs=pakwheels.com&cm=mobile-web-link&cn=organic-installs&cc=interstitial&hash=md5
# Inner Text:
# Title: None
# href: https://appgallery.huawei.com/#/app/C101437147
# Inner Text: Learn More
# Title: None
# href: /products/feature_your_ad
# Inner Text: Car Info
# Title: None
# href: #scroll_car_info
# Inner Text: Car Details
# Title: None
# href: #scroll_car_detail
# Inner Text: Seller's Comments
# Title: None
# href: #scroll_seller_comments
# Inner Text: Similar Ads
# Title: None
# href: #scroll_similar_ads
# Inner Text: Home
# Title: None
# href: /
# Inner Text: Used Cars
# Title: None
# href: /used-cars/
# Inner Text: Cars Vehari
# Title: Cars for sale in Vehari
# href: /used-cars/vehari/24851
# Inner Text: Suzuki Vehari
# Title: Suzuki Cars for sale in Vehari
# href: /used-cars/suzuki-vehari/461
# Inner Text: Alto Vehari
# Title: Suzuki Alto for Sale in Vehari
# href: /used-cars/suzuki-alto-vehari/1177
# Inner Text: Alto 2021 Vehari
# Title: Suzuki Alto 2021 Cars for sale in Vehari
# href: /used-cars/suzuki-alto-2021-vehari/680199
# Inner Text:  Hasilpur to Vehari Road, Vehari Punjab
# Title: None
# href: #
# Inner Text: Previous
# Title: None
# href: javascript:void(0);
# Inner Text: Next
# Title: None
# href: javascript:void(0);
# Inner Text:
# Title: None
# href: javascript:void(0);
# Inner Text:
# Title: None
# href: javascript:void(0);
# Inner Text:
#
#
# Title: None
# href: javascript:void(0)
# Inner Text: 2021
# Title: Year 2021 Cars for sale in Pakistan
# href: /used-cars/2021/651422
# Inner Text: Petrol
# Title: Petrol Cars for Sale in Pakistan
# href: /used-cars/petrol/57338
# Inner Text: Automatic
# Title: Automatic Cars for Sale in Pakistan
# href: /used-cars/automatic/57336
# Inner Text: Hatchback
# Title: Hatchback Cars for sale in Pakistan
# href: /used-cars/hatchback/107774
# Inner Text:
# Title: None
# href: /used-cars/dealers/suzuki-united-motors-showroom-in-vehari
# Inner Text: Suzuki United Motors
# Title: None
# href: /used-cars/dealers/suzuki-united-motors-showroom-in-vehari
# Inner Text: more ads by Suzuki United Motors »
# Title: None
# href: /used-cars/search/-/ds_suzuki-united-motors/
# Inner Text: Connect with facebook
# Title: None
# href: /oauth/facebook?rdback=true
# Inner Text: Learn More
# Title: None
# href: /safety-guide
# Inner Text:  Notify as Sold
# Title: Click to notify this ad as sold
# href: javascript:void(0);
# Inner Text:  Report this ad
# Title: Click here to report this ad
# href: javascript:void(0);
# Inner Text: Sell Your Car
# Title: None
# href: /used-cars/sell
# Inner Text:
#
#
#
#
#
# RECOMMENDED OIL FOR suzuki alto 2021
# Shell Helix Ultra
#
#
#
#
#
#
# See Shell Lube Recommender
#
#
#
# Title: None
# href: https://shell.pakwheels.com/generic-recommender/
# Inner Text:
#
#
#
#
#
# MAINTENANCE FREE BATTERY FOR suzuki alto 2021
# .
#
#
#
#
#
#
# Find Best Battery
#
#
#
# Title: None
# href: https://daewoobattery.com/automotive/
# Inner Text:
#
#
#
#
#
#
# Suzuki Alto VXR 2020
#
#                 PKR 1,950,000
#
#                 Vehari
#
# Title: None
# href: /used-cars/suzuki-alto-2020-for-sale-in-vehari-6850461
# Inner Text:
#
#
#
#
#
#
# Suzuki Alto VXR 2020
#
#                 PKR 1,900,000
#
#                 Vehari
#
# Title: None
# href: /used-cars/suzuki-alto-2020-for-sale-in-vehari-6838250
# Inner Text:
#
#
#
#
#
#
# Suzuki Alto VXR 2022
#
#                 PKR 2,125,000
#
#                 Vehari
#
# Title: None
# href: /used-cars/suzuki-alto-2022-for-sale-in-vehari-6454413
# Inner Text:
#
#
#
# 		    	FEATURED
#
#
#
#
#
#
#
#
#
# Suzuki Alto VXR 2021
#
#                 Call for price
#
#                 Vehari
#
# Title: None
# href: /used-cars/suzuki-alto-2021-for-sale-in-vehari-6812573
# Inner Text: Used Suzuki Alto 2022
# Title: Suzuki Alto 2022 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2022/849788
# Inner Text: Suzuki Alto 2019
# Title: Suzuki Alto 2019 for Sale in Pakistan
# href: /used-cars/suzuki-alto-2019/344202
# Inner Text: Suzuki Alto 2020
# Title: Suzuki Alto 2020 - Price, Cars for Sale in Pakistan
# href: /used-cars/suzuki-alto-2020/447081
# Inner Text: Alto 2007
# Title: Alto 2007 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2007/3162
# Inner Text: Alto 2011
# Title: Alto 2011 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2011/3166
# Inner Text: Alto 2006
# Title: Alto 2006 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2006/3161
# Inner Text: Alto 2012
# Title: Alto 2012 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2012/3167
# Inner Text: Alto 2010
# Title: Alto 2010 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2010/3165
# Inner Text: Alto 2008
# Title: Alto 2008 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2008/3163
# Inner Text: Alto 2009
# Title: Alto 2009 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2009/3164
# Inner Text: Alto 2005
# Title: Alto 2005 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2005/3160
# Inner Text: Alto 2004
# Title: Alto 2004 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2004/3159
# Inner Text: Alto 2015
# Title: Alto 2015 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2015/61834
# Inner Text: Alto 2014
# Title: Alto 2014 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2014/44977
# Inner Text: Alto 2018
# Title: Alto 2018 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2018/227455
# Inner Text: Alto 2016
# Title: Alto 2016 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2016/70335
# Inner Text: Alto 2013
# Title: Alto 2013 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2013/3168
# Inner Text: Alto 2017
# Title: Suzuki Alto 2017 for Sale in Pakistan
# href: /used-cars/suzuki-alto-2017/77438
# Inner Text: Alto 2003
# Title: Alto 2003 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2003/3158
# Inner Text: Alto 2001
# Title: Alto 2001 Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-2001/3156
# Inner Text: Alto for sale in Karachi
# Title: Alto for Sale in Karachi
# href: /used-cars/suzuki-alto-karachi/1180
# Inner Text: Alto for sale in Lahore
# Title: Alto Cars for sale in Lahore
# href: /used-cars/suzuki-alto-lahore/1181
# Inner Text: Alto for sale in Islamabad
# Title: Alto Cars for sale in Islamabad
# href: /used-cars/suzuki-alto-islamabad/1179
# Inner Text: Alto for sale in Rawalpindi
# Title: Alto Cars for sale in Rawalpindi
# href: /used-cars/suzuki-alto-rawalpindi/1169
# Inner Text: Alto for sale in Peshawar
# Title: Alto Cars for sale in Peshawar
# href: /used-cars/suzuki-alto-peshawar/1165
# Inner Text: Alto for sale in Multan
# Title: Alto Cars for sale in Multan
# href: /used-cars/suzuki-alto-multan/1159
# Inner Text: Alto for sale in Faisalabad
# Title: Alto Cars for sale in Faisalabad
# href: /used-cars/suzuki-alto-faisalabad/1141
# Inner Text: Alto Gujranwala
# Title: Suzuki Alto for Sale in Gujranwala
# href: /used-cars/suzuki-alto-gujranwala/1143
# Inner Text: Alto Hyderabad
# Title: Suzuki Alto for Sale in Hyderabad
# href: /used-cars/suzuki-alto-hyderabad/1147
# Inner Text: Alto Mardan
# Title: Suzuki Alto for Sale in Mardan
# href: /used-cars/suzuki-alto-mardan/1156
# Inner Text: Alto Sialkot
# Title: Suzuki Alto for Sale in Sialkot
# href: /used-cars/suzuki-alto-sialkot/1174
# Inner Text: Alto for sale in Abbottabad
# Title: Alto for sale in Abbottabad
# href: /used-cars/suzuki-alto-abbottabad/727517
# Inner Text: Alto Bahawalpur
# Title: Suzuki Alto for Sale in Bahawalpur
# href: /used-cars/suzuki-alto-bahawalpur/1136
# Inner Text: Alto Sargodha
# Title: Suzuki Alto for Sale in Sargodha
# Inner Text: Suzuki Cultus VXL
# Title: Suzuki Cultus VXL for sale in Pakistan
# href: /used-cars/suzuki-cultus-vxl/73445
# Inner Text: Suzuki Cultus VXRi
# Title: Suzuki Cultus VXRi for sale in Pakistan
# href: /used-cars/suzuki-cultus-vxri/73452
# Inner Text: Suzuki Alto VX
# Title: Suzuki Alto VX for sale in Pakistan
# href: /used-cars/suzuki-alto-vx/73648
# Inner Text: Suzuki Wagon R VXR
# Title: Suzuki Wagon R VXR Cars for sale in Pakistan
# href: /used-cars/suzuki-wagon-r-vxr/73897
# Inner Text: Suzuki Cultus VXLi
# Title: Suzuki Cultus VXLi for sale in Pakistan
# href: /used-cars/suzuki-cultus-vxli/73460
# Inner Text: Wagon R FX
# Title: Wagon R FX for sale in Pakistan
# href: /used-cars/suzuki-wagon-r-fx/232674
# Inner Text: Suzuki Wagon R Stingray
# Title: Suzuki Wagon R Stingray for sale in Pakistan
# href: /used-cars/suzuki-wagon-r-stingray/265370
# Inner Text: Suzuki Alto E
# Title: Suzuki Alto E Cars for sale in Pakistan
# href: /used-cars/suzuki-alto-E-/481844
# Inner Text: Suzuki Wagon R VX
# Title: Suzuki Wagon R VX Cars for sale in Pakistan
# href: /used-cars/suzuki-wagon-r-vx/106996
# Inner Text: Suzuki Alto 2021 Cars for sale in Vehari
# Title: Suzuki Alto 2021 Cars for sale in Vehari
# href: /used-cars/suzuki-alto-2021-vehari/680199
# Inner Text: Alto Automatic
# Title: Alto Automatic Cars for sale in Pakistan
# href: /used-cars/suzuki-alto/658?transmission=automatic
# Inner Text: Alto Petrol
# Title: Alto Petrol Cars for sale in Pakistan
# href: /used-cars/suzuki-alto/658?engine_type=petrol
# Inner Text: Silver Alto
# Title: Silver Alto Cars for sale in Pakistan
# href: /used-cars/suzuki-alto/658?color=silver
# Inner Text: Suzuki Alto Price in Pakistan
# Title: Suzuki Alto Price in Pakistan, Colors, Pictures & Reviews
# href: /new-cars/suzuki/alto/
# Inner Text: Suzuki Alto VXL AGS Specs & Features
# Title: Suzuki Alto VXL AGS Price in Pakistan, Specifications & Features
# href: /new-cars/suzuki/alto/vxl--2/
# Inner Text: Next
# Title: None
# href: /products/pakwheels-inspection?ad_id=6816909
# Inner Text:
#
#
# Title: None
# href: #
# Inner Text:
#
#
# Title: None
# href: #loginwithmobileSlider
# Inner Text:
#
#
# Title: None
# href: #loginwithmobileSlider
# Inner Text: Continue with Mobile Number
# Title: None
# href: None
# Inner Text:
#         Continue with Google
# Title: None
# href: /oauth/google
# Inner Text:
#         Continue with Facebook
# Title: None
# href: /oauth/facebook
# Inner Text:
#         Continue with Email
# Title: None
# href: javascript:void(0)
# Inner Text: Terms of Service
# Title: None
# href: /main/terms
# Inner Text: Privacy Policy
# Title: None
# href: /privacy-policy
# Inner Text:
# Title: None
# href: None
# Inner Text: Edit
# Title: None
# href: None
# Inner Text:
# Resend SMS
#
# Title: None
# href: None
# Inner Text: Request a Call
# Title: None
# href: None
# Inner Text: Submit
# Title: None
# href: None
# Inner Text:
# Title: None
# href: None
# Inner Text:
# Title: None
# href: None
# Inner Text: Terms of Service
# Title: None
# href: /main/terms
# Inner Text: Privacy Policy
# Title: None
# href: /privacy-policy
# Inner Text:
# Title: None
# href: None
# Inner Text:
# Title: PakWheels Android App
# href: https://play.google.com/store/apps/details?id=com.pakwheels&referrer=utm_source%3Dpakwheels.com%26utm_medium%3Dweb-link%26utm_content%3Dfooter%26utm_campaign%3Dorganic-installs
# Inner Text:
# Title: PakWheels iOS App
# href: https://click.google-analytics.com/redirect?tid=UA-642162-19&url=https%3A%2F%2Fitunes.apple.com%2Fpk%2Fapp%2Fpakwheels%2Fid739776365%3Fmt%3D8&aid=com.pakwheels.www&idfa={idfa}&cs=pakwheels.com&cm=web-link&cn=organic-installs&cc=footer&hash=md5
# Inner Text:
# Title: PakWheels Android App
# href: https://appgallery.huawei.com/#/app/C101437147
# Inner Text: Toyota Cars for Sale
# Title: Toyota Cars for Sale
# href: /used-cars/toyota/33
# Inner Text: Suzuki Cars for Sale
# Title: Suzuki Cars for Sale
# href: /used-cars/suzuki/32
# Inner Text: Honda Cars for Sale
# Title: Honda Cars for Sale
# href: /used-cars/honda/14
# Inner Text: Daihatsu Cars for Sale
# Title: Daihatsu Cars for Sale
# href: /used-cars/daihatsu/12
# Inner Text: Mitsubishi Cars for Sale
# Title: Mitsubishi Cars for Sale
# href: /used-cars/mitsubishi/25
# Inner Text: Nissan Cars for Sale
# Title: Nissan Cars for Sale
# href: /used-cars/nissan/26
# Inner Text: Mercedes Cars for Sale
# Title: Mercedes Cars for Sale
# href: /used-cars/mercedes-benz/23
# Inner Text: Hyundai Cars for Sale
# Title: Hyundai Cars for Sale
# href: /used-cars/hyundai/15
# Inner Text: BMW Cars for Sale
# Title: BMW Cars for Sale
# href: /used-cars/bmw/8
# Inner Text: Cars in Karachi
# Title: Cars for Sale in Karachi
# href: /used-cars/karachi/24857
# Inner Text: Cars in Lahore
# Title: Cars for Sale in Lahore
# href: /used-cars/lahore/24858
# Inner Text: Cars in Islamabad
# Title: Cars for Sale in Islamabad
# href: /used-cars/islamabad/24856
# Inner Text: Cars in Rawalpindi
# Title: Cars for Sale in Rawalpindi
# href: /used-cars/rawalpindi/24831
# Inner Text: Cars in Peshawar
# Title: Cars for Sale in Peshawar
# href: /used-cars/peshawar/24821
# Inner Text: Cars in Faisalabad
# Title: Cars for Sale in Faisalabad
# href: /used-cars/faisalabad/24753
# Inner Text: Cars in Multan
# Title: Cars for Sale in Multan
# href: /used-cars/multan/24810
# Inner Text: Cars in Gujranwala
# Title: Cars for Sale in Gujranwala
# href: /used-cars/gujranwala/24763
# Inner Text: Cars in Sialkot
# Title: Cars for Sale in Sialkot
# href: /used-cars/sialkot/24841
# Inner Text: Used Cars
# Title: Used Cars
# href: /used-cars/
# Inner Text: Used Bikes
# Title: Used Bikes
# href: /used-bikes/
# Inner Text: New Cars
# Title: New Cars
# href: /new-cars/
# Inner Text: Auto Parts & Accessories
# Title: Spare Parts and Accessories for Sale in Pakistan
# href: /accessories-spare-parts/search/-/buynow_1/
# Inner Text: Cool Rides
# Title: Cool Rides
# href: /rides/
# Inner Text: Forums
# Title: Forums
# href: https://www.pakwheels.com/forums/
# Inner Text: Autoshow
# Title: PakWheels Autoshow
# href: /autoshow
# Inner Text: Sitemap
# Title: Sitemap
# href: /sitemap/
# Inner Text: About PakWheels.com
# Title: About PakWheels.com
# href: /main/about_us
# Inner Text: Our Products
# Title: Our Products
# href: /products/
# Inner Text: Advertise With Us
# Title: Advertise With Us
# href: /products/advertise
# Inner Text: How To Pay
# Title: How To Pay
# href: /products/feature_your_ad#how_to_pay
# Inner Text: FAQs
# Title: FAQs
# href: /FAQ
# Inner Text: Refunds & Returns
# Title: Refunds & Returns
# href: /accessories-spare-parts/refunds-returns-policy/
# Inner Text: Careers
# Title: Careers
# href: http://pakeventures.simplicant.com/
# Inner Text: Contact Us
# Title: Contact Us
# href: /main/contact_us
# Inner Text: Jeep
# Title: Jeeps for sale in Pakistan
# href: /used-cars/jeep/72893
# Inner Text: Japanese Cars
# Title: Used Japanese Cars for sale in Pakistan - Japan Auction Cars
# href: /used-cars/japanese/65933
# Inner Text: Imported Cars
# Title: Imported Cars for Sale in Pakistan
# href: /used-cars/imported/57428
# Inner Text: Automatic Cars
# Title: Automatic Cars for Sale in Pakistan
# href: /used-cars/automatic/57336
# Inner Text: Low Priced Cars
# Title: Low Price Cars in Pakistan for Sale
# href: /used-cars/low-priced/328875
# Inner Text: 4x4 Cars
# Title: 4x4 Cars for sale in Pakistan - Four Wheel Cars
# href: /used-cars/4x4/107784
# Inner Text: 660cc Cars
# Title: 660cc Cars for Sale in Pakistan
# href: /used-cars/660cc-cars/190519
# Inner Text: 1000cc Cars
# Title: 1000cc Cars for Sale in Pakistan
# href: /used-cars/1000cc-cars/190769
# Inner Text: Sedan
# Title: Sedan Cars for Sale
# href: /used-cars/sedan/107775
# Inner Text: Hatchback
# Title: Hatchback Cars for Sale
# href: /used-cars/hatchback/107774
# Inner Text: SUV
# Title: SUV Cars for Sale
# href: /used-cars/suv/107776
# Inner Text: Crossover
# Title: Crossover Cars for Sale
# href: /used-cars/crossover/107782
# Inner Text: Mini Van
# Title: Mini Van Cars for Sale
# href: /used-cars/mini-van/107785
# Inner Text: Double Cabin
# Title: Double Cabin Cars for Sale
# href: /used-cars/double-cabin/266839
# Inner Text: Compact sedan
# Title: Compact sedan Cars for Sale
# href: /used-cars/compact-sedan/441106
# Inner Text: MPV
# Title: MPV Cars for Sale
# href: /used-cars/mpv/145760
# Inner Text: White Cars
# Title: White Cars for Sale
# href: /used-cars/white/107804
# Inner Text: Silver Cars
# Title: Silver Cars for Sale
# href: /used-cars/silver/107802
# Inner Text: Black Cars
# Title: Black Cars for Sale
# href: /used-cars/black/107787
# Inner Text: Grey Cars
# Title: Grey Cars for Sale
# href: /used-cars/grey/107794
# Inner Text: Blue Cars
# Title: Blue Cars for Sale
# href: /used-cars/blue/107788
# Inner Text: Red Cars
# Title: Red Cars for Sale
# href: /used-cars/red/107801
# Inner Text: Green Cars
# Title: Green Cars for Sale
# href: /used-cars/green/107793
# Inner Text: Gold Cars
# Title: Gold Cars for Sale
# href: /used-cars/gold/107792
# Inner Text: Cars in Punjab
# Title: Punjab Cars for Sale
# href: /used-cars/punjab/201902
# Inner Text: Cars in Sindh
# Title: Sindh Cars for Sale
# href: /used-cars/sindh/201932
# Inner Text: Cars in KPK
# Title: KPK Cars for Sale
# href: /used-cars/kpk/201917
# Inner Text: Cars in Balochistan
# Title: Balochistan Cars for Sale
# href: /used-cars/balochistan/201947
# Inner Text: Cars in Azad Kashmir
# Title: Azad Kashmir Cars for Sale
# href: /used-cars/azad-kashmir/201953
# Inner Text: Cars in Federally Administered Tribal Areas
# Title: Federally Administered Tribal Areas Cars for Sale
# href: /used-cars/federally-administered-tribal-areas/201951
# Inner Text: Sell Your Car
# Title: Sell Your Car in Pakistan
# href: /used-cars/sell
# Inner Text: Sell Your Bike
# Title: Sell Your Bike in Pakistan
# href: /used-bikes/sell
# Inner Text: Sell Accessory
# Title: Sell Autoparts & Accessories in Pakistan
# href: /accessories-spare-parts/sell
# Inner Text:
# Title: Follow Us On Twitter
# href: https://www.twitter.com/pakwheels
# Inner Text:
# Title: Follow Us On Facebook
# href: https://www.facebook.com/pakwheels
# Inner Text:
# Title: Follow Us On Google Plus
# href: https://plus.google.com/117775652035228984610
# Inner Text:
# Title: Follow Us On Pinterest
# href: https://pinterest.com/pakwheels/
# Inner Text:
# Title: Follow Us On Instagram
# href: https://instagram.com/pakwheels
# Inner Text:
# Title: Follow Us On Youtube
# href: https://www.youtube.com/user/pakwheels
# Inner Text: Download Mobile Apps
# Title: None
# href: /apps
# Inner Text:
# Title: PakWheels Android App
# href: https://play.google.com/store/apps/details?id=com.pakwheels&referrer=utm_source%3Dpakwheels.com%26utm_medium%3Dweb-link%26utm_content%3Dfooter%26utm_campaign%3Dorganic-installs
# Inner Text:
# Title: PakWheels iOS App
# href: https://click.google-analytics.com/redirect?tid=UA-642162-19&url=https%3A%2F%2Fitunes.apple.com%2Fpk%2Fapp%2Fpakwheels%2Fid739776365%3Fmt%3D8&aid=com.pakwheels.www&idfa={idfa}&cs=pakwheels.com&cm=web-link&cn=organic-installs&cc=footer&hash=md5
# Inner Text:
# Title: PakWheels Android App
# href: https://appgallery.huawei.com/#/app/C101437147
# Inner Text: Terms of Service
# Title: Terms of Service
# href: /main/terms
# Inner Text: Privacy Policy
# Title: Privacy Policy
# href: /privacy-policy

# %%
table = soup.find("table", attrs={"class": "table table-bordered text-center table-engine-detail fs16"})
info_table_data = table.tbody.find_all("tr")  # contains 2 rows
info_table_data
# Out:
# [<tr>
#  <td>
#  <span class="engine-icon year"></span>
#  <p><a href="/used-cars/2021/651422" title="Year 2021 Cars for sale in Pakistan">2021</a>
#  </p>
#  </td>
#  <td>
#  <span class="engine-icon millage"></span>
#  <p>63,000 km</p>
#  </td>
#  <td>
#  <span class="engine-icon type"></span>
#  <p><a href="/used-cars/petrol/57338" title="Petrol Cars for Sale in Pakistan">Petrol</a></p>
#  </td>
#  <td>
#  <span class="engine-icon transmission"></span>
#  <p><a href="/used-cars/automatic/57336" title="Automatic Cars for Sale in Pakistan">Automatic</a></p>
#  </td>
#  </tr>]

# %%
info_table_data[0].find_all("td")
# Out:
# [<td>
#  <span class="engine-icon year"></span>
#  <p><a href="/used-cars/2021/651422" title="Year 2021 Cars for sale in Pakistan">2021</a>
#  </p>
#  </td>,
#  <td>
#  <span class="engine-icon millage"></span>
#  <p>63,000 km</p>
#  </td>,
#  <td>
#  <span class="engine-icon type"></span>
#  <p><a href="/used-cars/petrol/57338" title="Petrol Cars for Sale in Pakistan">Petrol</a></p>
#  </td>,
#  <td>
#  <span class="engine-icon transmission"></span>
#  <p><a href="/used-cars/automatic/57336" title="Automatic Cars for Sale in Pakistan">Automatic</a></p>
#  </td>]

# %%
year_mileage_type_trans=[]
for td in info_table_data[0].find_all("td"):
    # remove any newlines and extra spaces from left and right
    year_mileage_type_trans.append(td.text.replace('\n', ' ').strip())

print(year_mileage_type_trans)
# Out:
# ['2021', '63,000 km', 'Petrol', 'Automatic']

# %%
year=[]
mileage=[]
fuel_type=[]
transmission=[]

# %%
year.append(year_mileage_type_trans[0])
mileage.append(year_mileage_type_trans[1])
fuel_type.append(year_mileage_type_trans[2])
transmission.append(year_mileage_type_trans[3])

# %%
otherData = soup.find("ul", attrs={"class": "list-unstyled ul-featured clearfix"})
otherData
# Out:
# <ul class="list-unstyled ul-featured clearfix" id="scroll_car_detail">
# <li class="ad-data">Registered In</li>
# <li>Abbottabad</li>
# <li class="ad-data">Color</li>
# <li>Silver</li>
# <li class="ad-data">Assembly</li>
# <li>Local</li>
# <li class="ad-data">Engine Capacity</li>
# <li>660 cc</li>
# <li class="ad-data">Body Type</li>
# <li><a href="/used-cars/hatchback/107774" title="Hatchback Cars for sale in Pakistan">Hatchback</a></li>
# <li class="ad-data">Last Updated:</li>
# <li>Nov 15, 2022</li>
# <li class="ad-data">Ad Ref #</li>
# <li>6816909</li>
# </ul>

# %%
city, color, assembly, engineCapacity = '','','',''

# %%
otherData.text
# Out:
# '\nRegistered In\nAbbottabad\nColor\nSilver\nAssembly\nLocal\nEngine Capacity\n660 cc\nBody Type\nHatchback\nLast Updated:\nNov 15, 2022\nAd Ref #\n6816909\n'

# %%
otherDataArray=[]
otherDataArray.append(otherData.text.replace('\n', ' ').strip())

# %%
otherDataArray
# Out:
# ['Registered In Abbottabad Color Silver Assembly Local Engine Capacity 660 cc Body Type Hatchback Last Updated: Nov 15, 2022 Ad Ref # 6816909']

# %%
city=otherDataArray[0][14:24]
city
# Out:
# 'Abbottabad'

# %%
color=otherDataArray[0][31:37]
color
# Out:
# 'Silver'

# %%
assembly=otherDataArray[0][47:52]
assembly
# Out:
# 'Local'

# %%
engineCapacity=otherDataArray[0][69:75]
engineCapacity
# Out:
# '660 cc'

# %%
#The data can be fetched dynamically, if we record actions using Selenium. Or, we extract the urls in the used cars and 
#see the pattern. Then the data will be stored in arrays, which will be then converted to dataframes and csv file. After that,
#we can perform other actions of filtering and creating APIs
